# %% [markdown]
# #Predicao PMC
#
# Este trabalho tem como objetivo a predicao da PMC - Pesquisa Mensal do Comercio .

# %%
pip install --upgrade xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xlrd in /usr/local/lib/python3.8/dist-packages (1.2.0)
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 KB 4.1 MB/s eta 0:00:00
# Installing collected packages: xlrd
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 1.2.0
#     Uninstalling xlrd-1.2.0:
#       Successfully uninstalled xlrd-1.2.0
# Successfully installed xlrd-2.0.1

# %%
# !pip install --upgrade pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (1.3.5)
# Collecting pandas
#   Downloading pandas-1.5.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 76.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
# Successfully installed pandas-1.5.3

# %%
# !pip install python-bcb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-bcb
#   Downloading python_bcb-0.1.8-py3-none-any.whl (15 kB)
# Collecting httpx<0.24.0,>=0.23.0
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas<2.0.0,>=1.4.4 in /usr/local/lib/python3.8/dist-packages (from python-bcb) (1.5.3)
# Requirement already satisfied: lxml<5.0.0,>=4.9.1 in /usr/local/lib/python3.8/dist-packages (from python-bcb) (4.9.2)
# Collecting requests<3.0.0,>=2.28.1
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 7.2 MB/s eta 0:00:00
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from httpx<0.24.0,>=0.23.0->python-bcb) (2022.12.7)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 KB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.4.4->python-bcb) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.4.4->python-bcb) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.4.4->python-bcb) (1.21.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.28.1->python-bcb) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.28.1->python-bcb) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.28.1->python-bcb) (2.10)
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 8.0 MB/s eta 0:00:00
# Collecting anyio<5.0,>=3.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.4.4->python-bcb) (1.15.0)
# Installing collected packages: rfc3986, sniffio, requests, h11, anyio, httpcore, httpx, python-bcb
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# Successfully installed anyio-3.6.2 h11-0.14.0 httpcore-0.16.3 httpx-0.23.3 python-bcb-0.1.8 requests-2.28.2 rfc3986-1.5.0 sniffio-1.3.0

# %%
# !pip install pmdarima
##Solucao https://blog.csdn.net/qq_49821869/article/details/128540436
import os
os.kill(os.getpid(),9)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pmdarima
#   Downloading pmdarima-2.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 29.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (0.29.33)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (57.4.0)
# Collecting statsmodels>=0.13.2
#   Downloading statsmodels-0.13.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 55.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.15.0)
# Installing collected packages: statsmodels, pmdarima
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.12.2
#     Uninstalling statsmodels-0.12.2:
#       Successfully uninstalled statsmodels-0.12.2
# Successfully installed pmdarima-2.0.2 statsmodels-0.13.5

# %% [markdown]
# #Importando bibliotecas

# %%
# !pip install sidrapy
import sidrapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sidrapy
#   Downloading sidrapy-0.1.4-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from sidrapy) (1.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from sidrapy) (2.28.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas->sidrapy) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.8/dist-packages (from pandas->sidrapy) (1.21.6)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas->sidrapy) (2022.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->sidrapy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->sidrapy) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->sidrapy) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests->sidrapy) (2.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas->sidrapy) (1.15.0)
# Installing collected packages: sidrapy
# Successfully installed sidrapy-0.1.4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date
from pmdarima import arima
import plotly.express as ploty
from datetime import datetime
from datetime import timedelta
import plotly.express as px
import plotly.graph_objs as go
import random

# %%
## testes de aderencia e estacionaridades
#https://www.statsmodels.org/dev/examples/notebooks/generated/stationarity_detrending_adf_kpss.html
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss

# %%
# %matplotlib inline
sns.set(rc={'figure.figsize':(20,10)})

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow import keras
tf.__version__
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# '2.11.0'

# %% [markdown]
# ##Biblioteca para deflacionar variavies no Brasil
#
# https://pypi.org/project/deflateBR/

# %%
# !pip install deflateBR
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deflateBR
#   Downloading deflateBR-0.2.1-py3-none-any.whl (6.3 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from deflateBR) (2.28.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from deflateBR) (1.21.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from deflateBR) (4.64.1)
# Collecting datetime
#   Downloading DateTime-5.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 KB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from deflateBR) (1.5.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from datetime->deflateBR) (2022.7.1)
# Collecting zope.interface
#   Downloading zope.interface-5.5.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 KB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas->deflateBR) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests->deflateBR) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->deflateBR) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->deflateBR) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->deflateBR) (2.10)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas->deflateBR) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from zope.interface->datetime->deflateBR) (57.4.0)
# Installing collected packages: zope.interface, datetime, deflateBR
# Successfully installed datetime-5.0 deflateBR-0.2.1 zope.interface-5.5.2

# %%
import deflatebr as dbr

# %% [markdown]
# #Importando dados

# %%
inicio = '2000-01-01'

# %% [markdown]
# ##Importando Pesquisa de Intenção de Consumo das Famílias (ICF) - CNC

# %%
import requests
import pandas as pd
import json
from datetime import datetime
import io

# Ler o arquivo JSON usando o método "get" da biblioteca "requests"
url = 'https://portal-backend-prod.azurewebsites.net/wp-json/wp/v2/publicacoes/462947'
response = requests.get(url)

# Carregar o conteúdo do arquivo como um dicionário Python
data = pd.read_json('https://portal-backend-prod.azurewebsites.net/wp-json/wp/v2/publicacoes/?publicacoes_categories=22&filter[orderby]=date&order=desc&search=&page=1&per_page=9')

# Filtrar as publicações com o slug "icf"
icf_publications = data[data['slug'].str.contains('icf')]

# Selecionar a publicação mais recente
icf_publications['date'] = pd.to_datetime(icf_publications['date']).dt.strftime('%Y-%m-%d')
data = icf_publications.sort_values('date', ascending=False)
ultima_data = data.iloc[0]['date']
most_recent_publication = data[data['date'] == ultima_data]

# Acessar a URL do anexo
attachment_url = most_recent_publication['_links'][0]['wp:attachment'][0]['href']
# Ler o arquivo JSON do anexo
attachment_response = requests.get(attachment_url)
attachment_data = json.loads(attachment_response.content)

# Acessar a URL do arquivo xls
xls_url = [d['source_url'] for d in attachment_data if '.xls' in d['source_url']]
xls_url
# Ler o arquivo xls com o Pandas
df = pd.read_excel(xls_url[0], sheet_name='Índices (sem ajuste)')

# Selecionar as colunas "date" e "ICF"
df = df.iloc[:,[0,1]]
df.columns = ['date','ICF']
df.index = df['date']
df_icf = df.drop('date',axis=1)
# Out:
# <ipython-input-12-86befc9dd1e2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   icf_publications['date'] = pd.to_datetime(icf_publications['date']).dt.strftime('%Y-%m-%d')

# %%
most_recent_publication['_links']
# Out:
# 0    {'self': [{'href': 'https://portal-backend-pro...
# Name: _links, dtype: object

# %%
df_icf
# Out:
#              ICF
# date
# 2022-02-01 77.56
# 2022-03-01 78.14
# 2022-04-01 78.55
# 2022-05-01 79.46
# 2022-06-01 80.17
# 2022-07-01 80.75
# 2022-08-01 82.13
# 2022-09-01 84.44
# 2022-10-01 87.02
# 2022-11-01 88.98
# 2022-12-01 91.27
# 2023-01-01 93.87
# 2023-02-01 95.67

# %% [markdown]
# ##Importando  Pesquisa de Endividamento e Inadimplência do Consumidor (Peic) CNC

# %%
# Ler o arquivo JSON usando o método "get" da biblioteca "requests"
url = 'https://portal-backend-prod.azurewebsites.net/wp-json/wp/v2/publicacoes/462947'
response = requests.get(url)

# Carregar o conteúdo do arquivo como um dicionário Python
data = pd.read_json('https://portal-backend-prod.azurewebsites.net/wp-json/wp/v2/publicacoes/?publicacoes_categories=22&filter[orderby]=date&order=desc&search=&page=1&per_page=9')

# Filtrar as publicações com o slug "peic"
peic_publications = data[data['slug'].str.contains('peic')]

# Selecionar a publicação mais recente
peic_publications['date'] = pd.to_datetime(peic_publications['date']).dt.strftime('%Y-%m-%d')
data = peic_publications.sort_values('date', ascending=False)
ultima_data = data.iloc[0]['date']
most_recent_publication = data[data['date'] == ultima_data]

# Acessar a URL do anexo
attachment_url = most_recent_publication['_links'][3]['wp:attachment'][0]['href']
# Ler o arquivo JSON do anexo
attachment_response = requests.get(attachment_url)
attachment_data = json.loads(attachment_response.content)

# Acessar a URL do arquivo xls
xls_url = [d['source_url'] for d in attachment_data if '.xls' in d['source_url']]
xls_url
# Ler o arquivo xls com o Pandas
df = pd.read_excel(xls_url[0], sheet_name='PEIC')

##Tratando os dados
df = df.T
df.columns = df.iloc[0,:]
df = df[1:]
df.index = pd.to_datetime(df.index).strftime('%Y-%m-%d')

## selecioanando variaveis
lista= ['Familias Endividadas (% do total de famílias)',
       'Familias com dívidas em atraso (% do total de famílias)',
       'Não terão condição de pagar dívidas em atraso (% do total de famílias)']
df_peic = df.loc[:,lista]
df_peic.index = pd.to_datetime(df_peic.index)
df_peic
# Out:
# <ipython-input-16-d92b3b846c90>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   peic_publications['date'] = pd.to_datetime(peic_publications['date']).dt.strftime('%Y-%m-%d')
# Unnamed: 0 Familias Endividadas (% do total de famílias)  \
# 2022-01-01                                          0.76
# 2022-02-01                                          0.77
# 2022-03-01                                          0.77
# 2022-04-01                                          0.78
# 2022-05-01                                          0.77
# 2022-06-01                                          0.77
# 2022-07-01                                          0.78
# 2022-08-01                                          0.79
# 2022-09-01                                          0.79
# 2022-10-01                                          0.79
# 2022-11-01                                          0.79
# 2022-12-01                                          0.78
# 2023-01-01                                          0.78
#
# Unnamed: 0 Familias com dívidas em atraso (% do total de famílias)  \
# 2022-01-01                                               0.26
# 2022-02-01                                               0.27
# 2022-03-01                                               0.28
# 2022-04-01                                               0.29
# 2022-05-01                                               0.29
# 2022-06-01                                               0.29
# 2022-07-01                                               0.29
# 2022-08-01                                               0.30
# 2022-09-01                                               0.30
# 2022-10-01                                               0.30
# 2022-11-01                                               0.30
# 2022-12-01                                               0.30
# 2023-01-01                                               0.30
#
# Unnamed: 0 Não terão condição de pagar dívidas em atraso (% do total de famílias)
# 2022-01-01                                               0.10
# 2022-02-01                                               0.11
# 2022-03-01                                               0.11
# 2022-04-01                                               0.11
# 2022-05-01                                               0.11
# 2022-06-01                                               0.11
# 2022-07-01                                               0.11
# 2022-08-01                                               0.11
# 2022-09-01                                               0.11
# 2022-10-01                                               0.11
# 2022-11-01                                               0.11
# 2022-12-01                                               0.11
# 2023-01-01                                               0.12

# %%
most_recent_publication['_links']
# Out:
# 3    {'self': [{'href': 'https://portal-backend-pro...
# Name: _links, dtype: object

# %% [markdown]
# ##Indicador de atividade do comercio(Seraza experian)

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL do site
www_iac = "https://www.serasaexperian.com.br/conteudos/indicadores-economicos/"

# enviar requisição
response = requests.get(www_iac)

# parsear o HTML
soup = BeautifulSoup(response.text, "html.parser")

# obter o link
link = soup.select_one("#main > section > div > div > div > section:nth-of-type(2) > div > div > div > div > div:nth-of-type(1) > div:nth-of-type(1) > div:nth-of-type(2) > a")["href"]

# ler o arquivo
df_atividade = pd.read_excel(link, sheet_name="Com Ajuste Sazonal",skiprows=2)

# remover linhas com valores faltantes
df_atividade.dropna(axis=0,inplace=True)

# Tratando os dados
df_atividade.rename(columns= {'Mês':'ano'},inplace=True) 
df_atividade.index = pd.to_datetime(df_atividade['ano'])
df_atividade.drop('ano',axis=1,inplace=True)

#Selecionando variaveis
df_atividade = df_atividade[['Geral']]
df_atividade
# Out:
#             Geral
# ano
# 2000-01-01  46.55
# 2000-02-01  51.33
# 2000-03-01  47.64
# 2000-04-01  49.45
# 2000-05-01  50.71
# ...           ...
# 2022-08-01  78.87
# 2022-09-01  79.00
# 2022-10-01  78.54
# 2022-11-01  80.28
# 2022-12-01  81.07
#
# [276 rows x 1 columns]

# %% [markdown]
# ##Falências, Recuperações Judiciais e Concordatas - Serasa Experian

# %%
# URL do site
www_iac = "https://www.serasaexperian.com.br/conteudos/indicadores-economicos/"

# enviar requisição
response = requests.get(www_iac)

# parsear o HTML
soup = BeautifulSoup(response.text, "html.parser")

# obter o link
link = soup.select_one("#main > section > div > div > div > section:nth-of-type(2) > div > div > div > div > div:nth-of-type(5) > div:nth-of-type(1) > div:nth-of-type(2) > a")["href"]

# ler o arquivo
df_falencia = pd.read_excel(link, sheet_name="Total de Ocorrências Setor",skiprows=4)

# remover linhas com valores faltantes
#df_falencia.dropna(axis=0,inplace=True)

# Tratando os dados
df_falencia.rename(columns= {'Unnamed: 0':'ano'},inplace=True) 
df_falencia.index = pd.to_datetime(df_falencia['ano'])
df_falencia.drop('ano',axis=1,inplace=True)

#Selecionando variaveis
df_falencia = df_falencia[['Comércio']]
df_falencia.dropna(axis=0,inplace=True)
df_falencia
# Out:
#             Comércio
# ano
# 1991-01-01         0
# 1991-02-01         0
# 1991-03-01         0
# 1991-04-01         0
# 1991-05-01         0
# ...              ...
# 2022-08-01        31
# 2022-09-01        14
# 2022-10-01        10
# 2022-11-01        24
# 2022-12-01        10
#
# [384 rows x 1 columns]

# %% [markdown]
# ##Indicador de Nascimento de Empresas - Serasa Experian

# %%
# URL do site
www_iac = "https://www.serasaexperian.com.br/conteudos/indicadores-economicos/"

# enviar requisição
response = requests.get(www_iac)

# parsear o HTML
soup = BeautifulSoup(response.text, "html.parser")

# obter o link
link = soup.select_one("#main > section > div > div > div > section:nth-of-type(2) > div > div > div > div > div:nth-of-type(9) > div:nth-of-type(1) > div:nth-of-type(2) > a")["href"]

# ler o arquivo
df_nascimento = pd.read_excel(link, sheet_name="Qtde. Mensal",skiprows=3)

# Tratando os dados
df_nascimento.rename(columns= {'Mês':'ano'},inplace=True) 
df_nascimento['ano'] = np.where(df_nascimento['ano'] == 'fev-16',pd.to_datetime('2016-02-01'),df_nascimento['ano'])
df_nascimento.index = pd.to_datetime(df_nascimento['ano'])
df_nascimento.drop('ano',axis=1,inplace=True)

#Selecionando variaveis
df_nascimento = df_nascimento[['Comércio']]
df_nascimento
# Out:
#             Comércio
# ano
# 2010-01-01  25664.00
# 2010-02-01  36657.00
# 2010-03-01  50570.00
# 2010-04-01  41868.00
# 2010-05-01  48516.00
# ...              ...
# 2022-08-01  81825.00
# 2022-09-01  69551.00
# 2022-10-01  65679.00
# 2022-11-01       NaN
# 2022-12-01       NaN
#
# [156 rows x 1 columns]

# %% [markdown]
# ##Indicador de Demanda do Consumidor por Crédito - Serasa Experian

# %%
# URL do site
www_iac = "https://www.serasaexperian.com.br/conteudos/indicadores-economicos/"

# enviar requisição
response = requests.get(www_iac)

# parsear o HTML
soup = BeautifulSoup(response.text, "html.parser")

# obter o link
link = soup.select_one("#main > section > div > div > div > section:nth-of-type(2) > div > div > div > div > div:nth-of-type(3) > div:nth-of-type(1) > div:nth-of-type(2) > a")["href"]

# ler o arquivo
df_credito = pd.read_excel(link, sheet_name="Consumidor",skiprows=3)

# Tratando os dados
df_credito.rename(columns= {'Mês':'ano'},inplace=True) 
df_credito.index = pd.to_datetime(df_credito['ano'])
df_credito.drop('ano',axis=1,inplace=True)

#Selecionando variaveis
df_credito = df_credito[['Total']]
df_credito
# Out:
#             Total
# ano
# 2007-01-01  48.34
# 2007-02-01  43.28
# 2007-03-01  51.70
# 2007-04-01  47.16
# 2007-05-01  52.48
# ...           ...
# 2022-08-01 106.37
# 2022-09-01  97.41
# 2022-10-01  91.33
# 2022-11-01  87.86
# 2022-12-01  77.28
#
# [192 rows x 1 columns]

# %% [markdown]
# ## Meio de Pagamento - Ampliado - M2 - depósitos em poupança - fim de período (IPEADATA)

# %%
#!pip install ipeadatapy
#import ipeadatapy as ip

# %%
#Lista das series
#codigos = ip.list_series()

# %%
#codigos[codigos.CODE == 'BM12_DEPOUCNY12']

# %%
import requests
import pandas as pd

code_ipea = "BM12_DEPOUCNY12"
url = f"http://ipeadata.gov.br/api/odata4/ValoresSerie(SERCODIGO='{code_ipea}')"

response = requests.get(url)
data = response.json()

df_poupanca = pd.DataFrame(data["value"])
df_poupanca = df_poupanca[["VALDATA", "VALVALOR"]]
df_poupanca.rename(columns={"VALDATA": "date", "VALVALOR": "poupanca"}, inplace=True)
df_poupanca['date'] = df_poupanca['date'].apply(lambda x: str(x).split('T')[0])
df_poupanca.index =pd.to_datetime(df_poupanca["date"])
df_poupanca = df_poupanca[['poupanca']]

df_poupanca
# Out:
#             poupanca
# date
# 1990-01-01     31.48
# 1990-02-01     41.27
# 1990-03-01     34.75
# 1990-04-01     16.54
# 1990-05-01     10.97
# ...              ...
# 2022-08-01     10.40
# 2022-09-01     10.32
# 2022-10-01     10.19
# 2022-11-01     10.11
# 2022-12-01     10.16
#
# [396 rows x 1 columns]

# %% [markdown]
# ##Índice Cielo de Varejo Ampliado (ICVA)

# %%
df_icva = pd.read_excel('https://apicatalog.mziq.com/filemanager/v2/d/4d1ebe73-b068-4443-992a-3d72d573238c/3e864198-0b72-c970-1771-80cd8c338a30?origin=2',skiprows=6)
df_icva = df_icva.iloc[:4,3:]
df_icva = df_icva.T
df_icva.columns = df_icva.iloc[0,:]
df_icva = df_icva[1:]
df_icva = df_icva[['Deflacionado - Com Ajuste Calendário']]
df_icva.index = pd.to_datetime(df_icva.index)

# %%
df_icva
# Out:
# Visão      Deflacionado - Com Ajuste Calendário
# 2013-01-01                                 0.07
# 2013-02-01                                 0.06
# 2013-03-01                                 0.06
# 2013-04-01                                 0.07
# 2013-05-01                                 0.06
# ...                                         ...
# 2021-05-01                                 0.20
# 2021-06-01                                 0.09
# 2021-07-01                                 0.06
# 2021-08-01                                 0.02
# 2021-09-01                                 0.01
#
# [105 rows x 1 columns]

# %% [markdown]
# ##Importando dados Banco Central

# %%
# !pip install python-bcb
from bcb import sgs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: python-bcb in /usr/local/lib/python3.8/dist-packages (0.1.8)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.8/dist-packages (from python-bcb) (2.28.2)
# Requirement already satisfied: pandas<2.0.0,>=1.4.4 in /usr/local/lib/python3.8/dist-packages (from python-bcb) (1.5.3)
# Requirement already satisfied: lxml<5.0.0,>=4.9.1 in /usr/local/lib/python3.8/dist-packages (from python-bcb) (4.9.2)
# Requirement already satisfied: httpx<0.24.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from python-bcb) (0.23.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.8/dist-packages (from httpx<0.24.0,>=0.23.0->python-bcb) (1.3.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /usr/local/lib/python3.8/dist-packages (from httpx<0.24.0,>=0.23.0->python-bcb) (1.5.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from httpx<0.24.0,>=0.23.0->python-bcb) (2022.12.7)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /usr/local/lib/python3.8/dist-packages (from httpx<0.24.0,>=0.23.0->python-bcb) (0.16.3)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.4.4->python-bcb) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.4.4->python-bcb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.4.4->python-bcb) (2022.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.28.1->python-bcb) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.28.1->python-bcb) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.28.1->python-bcb) (2.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.8/dist-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->python-bcb) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.8/dist-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->python-bcb) (3.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.4.4->python-bcb) (1.15.0)

# %%
date_range = pd.date_range(start=inicio, end=datetime.today(), freq='MS')
date_range
# Out:
# DatetimeIndex(['2000-01-01', '2000-02-01', '2000-03-01', '2000-04-01',
#                '2000-05-01', '2000-06-01', '2000-07-01', '2000-08-01',
#                '2000-09-01', '2000-10-01',
#                ...
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01'],
#               dtype='datetime64[ns]', length=278, freq='MS')

# %%
dados_completo = pd.DataFrame(index = date_range)

# %% [markdown]
# #### Comprometimento de renda das famílias - Serviço da dívida ex-habit - Com ajuste sazonal

# %%
dados_completo['comprometimento_renda'] = sgs.get({'comprometimento_renda':20399})

# %%
dados_completo
# Out:
#             comprometimento_renda
# 2000-01-01                    NaN
# 2000-02-01                    NaN
# 2000-03-01                    NaN
# 2000-04-01                    NaN
# 2000-05-01                    NaN
# ...                           ...
# 2022-10-01                    NaN
# 2022-11-01                    NaN
# 2022-12-01                    NaN
# 2023-01-01                    NaN
# 2023-02-01                    NaN
#
# [278 rows x 1 columns]

# %% [markdown]
# ###Consumo de energia elétrica - Comercial

# %%
dados_completo['cons_energia_com'] = sgs.get({'cons_energia_com':1402})
dados_completo
# Out:
#             comprometimento_renda  cons_energia_com
# 2000-01-01                    NaN           4083.00
# 2000-02-01                    NaN           4016.00
# 2000-03-01                    NaN           4099.00
# 2000-04-01                    NaN           4065.00
# 2000-05-01                    NaN           3931.00
# ...                           ...               ...
# 2022-10-01                    NaN           7483.00
# 2022-11-01                    NaN           7721.00
# 2022-12-01                    NaN               NaN
# 2023-01-01                    NaN               NaN
# 2023-02-01                    NaN               NaN
#
# [278 rows x 2 columns]

# %% [markdown]
# ###Dólar americano (venda) - fim de período

# %%
dados_completo['cambio'] = sgs.get({'cambio':3696},start=inicio)
dados_completo
# Out:
#             comprometimento_renda  cons_energia_com  cambio
# 2000-01-01                    NaN           4083.00    1.80
# 2000-02-01                    NaN           4016.00    1.77
# 2000-03-01                    NaN           4099.00    1.75
# 2000-04-01                    NaN           4065.00    1.81
# 2000-05-01                    NaN           3931.00    1.83
# ...                           ...               ...     ...
# 2022-10-01                    NaN           7483.00    5.26
# 2022-11-01                    NaN           7721.00    5.29
# 2022-12-01                    NaN               NaN    5.22
# 2023-01-01                    NaN               NaN    5.10
# 2023-02-01                    NaN               NaN     NaN
#
# [278 rows x 3 columns]

# %% [markdown]
# ### Endividamento das famílias exceto crédito habitacional

# %%
dados_completo['endividamento_exhabit'] = sgs.get({'endividamento_exhabit':20400})
dados_completo
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2000-01-01                    NaN           4083.00    1.80
# 2000-02-01                    NaN           4016.00    1.77
# 2000-03-01                    NaN           4099.00    1.75
# 2000-04-01                    NaN           4065.00    1.81
# 2000-05-01                    NaN           3931.00    1.83
# ...                           ...               ...     ...
# 2022-10-01                    NaN           7483.00    5.26
# 2022-11-01                    NaN           7721.00    5.29
# 2022-12-01                    NaN               NaN    5.22
# 2023-01-01                    NaN               NaN    5.10
# 2023-02-01                    NaN               NaN     NaN
#
#             endividamento_exhabit
# 2000-01-01                    NaN
# 2000-02-01                    NaN
# 2000-03-01                    NaN
# 2000-04-01                    NaN
# 2000-05-01                    NaN
# ...                           ...
# 2022-10-01                    NaN
# 2022-11-01                    NaN
# 2022-12-01                    NaN
# 2023-01-01                    NaN
# 2023-02-01                    NaN
#
# [278 rows x 4 columns]

# %% [markdown]
# ###Indicador de Movimento de Cheques - Dados dessazonalizados

# %%
dados_completo['cheques'] = sgs.get({'cheques':28551})
dados_completo
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2000-01-01                    NaN           4083.00    1.80
# 2000-02-01                    NaN           4016.00    1.77
# 2000-03-01                    NaN           4099.00    1.75
# 2000-04-01                    NaN           4065.00    1.81
# 2000-05-01                    NaN           3931.00    1.83
# ...                           ...               ...     ...
# 2022-10-01                    NaN           7483.00    5.26
# 2022-11-01                    NaN           7721.00    5.29
# 2022-12-01                    NaN               NaN    5.22
# 2023-01-01                    NaN               NaN    5.10
# 2023-02-01                    NaN               NaN     NaN
#
#             endividamento_exhabit    cheques
# 2000-01-01                    NaN        NaN
# 2000-02-01                    NaN        NaN
# 2000-03-01                    NaN        NaN
# 2000-04-01                    NaN        NaN
# 2000-05-01                    NaN        NaN
# ...                           ...        ...
# 2022-10-01                    NaN 2631856.00
# 2022-11-01                    NaN        NaN
# 2022-12-01                    NaN        NaN
# 2023-01-01                    NaN        NaN
# 2023-02-01                    NaN        NaN
#
# [278 rows x 5 columns]

# %% [markdown]
# ###Indicador de Movimento do Comércio a Prazo - IMC - Dados dessazonalizados

# %%
dados_completo['imc'] = sgs.get({'imc':28550})
dados_completo
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2000-01-01                    NaN           4083.00    1.80
# 2000-02-01                    NaN           4016.00    1.77
# 2000-03-01                    NaN           4099.00    1.75
# 2000-04-01                    NaN           4065.00    1.81
# 2000-05-01                    NaN           3931.00    1.83
# ...                           ...               ...     ...
# 2022-10-01                    NaN           7483.00    5.26
# 2022-11-01                    NaN           7721.00    5.29
# 2022-12-01                    NaN               NaN    5.22
# 2023-01-01                    NaN               NaN    5.10
# 2023-02-01                    NaN               NaN     NaN
#
#             endividamento_exhabit    cheques        imc
# 2000-01-01                    NaN        NaN        NaN
# 2000-02-01                    NaN        NaN        NaN
# 2000-03-01                    NaN        NaN        NaN
# 2000-04-01                    NaN        NaN        NaN
# 2000-05-01                    NaN        NaN        NaN
# ...                           ...        ...        ...
# 2022-10-01                    NaN 2631856.00 1742839.00
# 2022-11-01                    NaN        NaN        NaN
# 2022-12-01                    NaN        NaN        NaN
# 2023-01-01                    NaN        NaN        NaN
# 2023-02-01                    NaN        NaN        NaN
#
# [278 rows x 6 columns]

# %% [markdown]
# ###Índice de Confiança do Consumidor

# %%
dados_completo['icc_fecomercio'] = sgs.get({'icc_fecomercio':4393})
dados_completo
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2000-01-01                    NaN           4083.00    1.80
# 2000-02-01                    NaN           4016.00    1.77
# 2000-03-01                    NaN           4099.00    1.75
# 2000-04-01                    NaN           4065.00    1.81
# 2000-05-01                    NaN           3931.00    1.83
# ...                           ...               ...     ...
# 2022-10-01                    NaN           7483.00    5.26
# 2022-11-01                    NaN           7721.00    5.29
# 2022-12-01                    NaN               NaN    5.22
# 2023-01-01                    NaN               NaN    5.10
# 2023-02-01                    NaN               NaN     NaN
#
#             endividamento_exhabit    cheques        imc  icc_fecomercio
# 2000-01-01                    NaN        NaN        NaN          100.91
# 2000-02-01                    NaN        NaN        NaN          107.34
# 2000-03-01                    NaN        NaN        NaN          100.09
# 2000-04-01                    NaN        NaN        NaN           93.93
# 2000-05-01                    NaN        NaN        NaN           89.44
# ...                           ...        ...        ...             ...
# 2022-10-01                    NaN 2631856.00 1742839.00          114.23
# 2022-11-01                    NaN        NaN        NaN          116.79
# 2022-12-01                    NaN        NaN        NaN          122.84
# 2023-01-01                    NaN        NaN        NaN          125.38
# 2023-02-01                    NaN        NaN        NaN             NaN
#
# [278 rows x 7 columns]

# %% [markdown]
# ###Índice nacional de preços ao consumidor-amplo (IPCA)

# %%
dados_completo['ipca'] = sgs.get({'ipca':433})
dados_completo
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2000-01-01                    NaN           4083.00    1.80
# 2000-02-01                    NaN           4016.00    1.77
# 2000-03-01                    NaN           4099.00    1.75
# 2000-04-01                    NaN           4065.00    1.81
# 2000-05-01                    NaN           3931.00    1.83
# ...                           ...               ...     ...
# 2022-10-01                    NaN           7483.00    5.26
# 2022-11-01                    NaN           7721.00    5.29
# 2022-12-01                    NaN               NaN    5.22
# 2023-01-01                    NaN               NaN    5.10
# 2023-02-01                    NaN               NaN     NaN
#
#             endividamento_exhabit    cheques        imc  icc_fecomercio  ipca
# 2000-01-01                    NaN        NaN        NaN          100.91  0.62
# 2000-02-01                    NaN        NaN        NaN          107.34  0.13
# 2000-03-01                    NaN        NaN        NaN          100.09  0.22
# 2000-04-01                    NaN        NaN        NaN           93.93  0.42
# 2000-05-01                    NaN        NaN        NaN           89.44  0.01
# ...                           ...        ...        ...             ...   ...
# 2022-10-01                    NaN 2631856.00 1742839.00          114.23  0.59
# 2022-11-01                    NaN        NaN        NaN          116.79  0.41
# 2022-12-01                    NaN        NaN        NaN          122.84  0.62
# 2023-01-01                    NaN        NaN        NaN          125.38  0.53
# 2023-02-01                    NaN        NaN        NaN             NaN   NaN
#
# [278 rows x 8 columns]

# %% [markdown]
# ### Massa Salarial Ampliada Disponível - PNADC (média móvel trimestral)

# %%
dados_completo['msad'] = sgs.get({'msad':22079})
dados_completo
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2000-01-01                    NaN           4083.00    1.80
# 2000-02-01                    NaN           4016.00    1.77
# 2000-03-01                    NaN           4099.00    1.75
# 2000-04-01                    NaN           4065.00    1.81
# 2000-05-01                    NaN           3931.00    1.83
# ...                           ...               ...     ...
# 2022-10-01                    NaN           7483.00    5.26
# 2022-11-01                    NaN           7721.00    5.29
# 2022-12-01                    NaN               NaN    5.22
# 2023-01-01                    NaN               NaN    5.10
# 2023-02-01                    NaN               NaN     NaN
#
#             endividamento_exhabit    cheques        imc  icc_fecomercio  ipca  \
# 2000-01-01                    NaN        NaN        NaN          100.91  0.62
# 2000-02-01                    NaN        NaN        NaN          107.34  0.13
# 2000-03-01                    NaN        NaN        NaN          100.09  0.22
# 2000-04-01                    NaN        NaN        NaN           93.93  0.42
# 2000-05-01                    NaN        NaN        NaN           89.44  0.01
# ...                           ...        ...        ...             ...   ...
# 2022-10-01                    NaN 2631856.00 1742839.00          114.23  0.59
# 2022-11-01                    NaN        NaN        NaN          116.79  0.41
# 2022-12-01                    NaN        NaN        NaN          122.84  0.62
# 2023-01-01                    NaN        NaN        NaN          125.38  0.53
# 2023-02-01                    NaN        NaN        NaN             NaN   NaN
#
#             msad
# 2000-01-01   NaN
# 2000-02-01   NaN
# 2000-03-01   NaN
# 2000-04-01   NaN
# 2000-05-01   NaN
# ...          ...
# 2022-10-01   NaN
# 2022-11-01   NaN
# 2022-12-01   NaN
# 2023-01-01   NaN
# 2023-02-01   NaN
#
# [278 rows x 9 columns]

# %% [markdown]
# ###Estoque de empregos formais – Comércio – Dados dessazonalizados - CAGED

# %%
dados_completo['estoque_empregos_com'] = sgs.get({'estoque_empregos_com':28792})
dados_completo
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2000-01-01                    NaN           4083.00    1.80
# 2000-02-01                    NaN           4016.00    1.77
# 2000-03-01                    NaN           4099.00    1.75
# 2000-04-01                    NaN           4065.00    1.81
# 2000-05-01                    NaN           3931.00    1.83
# ...                           ...               ...     ...
# 2022-10-01                    NaN           7483.00    5.26
# 2022-11-01                    NaN           7721.00    5.29
# 2022-12-01                    NaN               NaN    5.22
# 2023-01-01                    NaN               NaN    5.10
# 2023-02-01                    NaN               NaN     NaN
#
#             endividamento_exhabit    cheques        imc  icc_fecomercio  ipca  \
# 2000-01-01                    NaN        NaN        NaN          100.91  0.62
# 2000-02-01                    NaN        NaN        NaN          107.34  0.13
# 2000-03-01                    NaN        NaN        NaN          100.09  0.22
# 2000-04-01                    NaN        NaN        NaN           93.93  0.42
# 2000-05-01                    NaN        NaN        NaN           89.44  0.01
# ...                           ...        ...        ...             ...   ...
# 2022-10-01                    NaN 2631856.00 1742839.00          114.23  0.59
# 2022-11-01                    NaN        NaN        NaN          116.79  0.41
# 2022-12-01                    NaN        NaN        NaN          122.84  0.62
# 2023-01-01                    NaN        NaN        NaN          125.38  0.53
# 2023-02-01                    NaN        NaN        NaN             NaN   NaN
#
#             msad  estoque_empregos_com
# 2000-01-01   NaN            3385641.36
# 2000-02-01   NaN            3397098.93
# 2000-03-01   NaN            3425390.06
# 2000-04-01   NaN            3436131.05
# 2000-05-01   NaN            3444717.86
# ...          ...                   ...
# 2022-10-01   NaN            9906221.34
# 2022-11-01   NaN            9931863.43
# 2022-12-01   NaN            9956096.85
# 2023-01-01   NaN                   NaN
# 2023-02-01   NaN                   NaN
#
# [278 rows x 10 columns]

# %% [markdown]
# ### Taxa de juros - Selic acumulada no mês anualizada base

# %%
dados_completo['selic'] = sgs.get({'selic':4189})
dados_completo
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2000-01-01                    NaN           4083.00    1.80
# 2000-02-01                    NaN           4016.00    1.77
# 2000-03-01                    NaN           4099.00    1.75
# 2000-04-01                    NaN           4065.00    1.81
# 2000-05-01                    NaN           3931.00    1.83
# ...                           ...               ...     ...
# 2022-10-01                    NaN           7483.00    5.26
# 2022-11-01                    NaN           7721.00    5.29
# 2022-12-01                    NaN               NaN    5.22
# 2023-01-01                    NaN               NaN    5.10
# 2023-02-01                    NaN               NaN     NaN
#
#             endividamento_exhabit    cheques        imc  icc_fecomercio  ipca  \
# 2000-01-01                    NaN        NaN        NaN          100.91  0.62
# 2000-02-01                    NaN        NaN        NaN          107.34  0.13
# 2000-03-01                    NaN        NaN        NaN          100.09  0.22
# 2000-04-01                    NaN        NaN        NaN           93.93  0.42
# 2000-05-01                    NaN        NaN        NaN           89.44  0.01
# ...                           ...        ...        ...             ...   ...
# 2022-10-01                    NaN 2631856.00 1742839.00          114.23  0.59
# 2022-11-01                    NaN        NaN        NaN          116.79  0.41
# 2022-12-01                    NaN        NaN        NaN          122.84  0.62
# 2023-01-01                    NaN        NaN        NaN          125.38  0.53
# 2023-02-01                    NaN        NaN        NaN             NaN   NaN
#
#             msad  estoque_empregos_com  selic
# 2000-01-01   NaN            3385641.36  18.94
# 2000-02-01   NaN            3397098.93  18.87
# 2000-03-01   NaN            3425390.06  18.85
# 2000-04-01   NaN            3436131.05  18.62
# 2000-05-01   NaN            3444717.86  18.51
# ...          ...                   ...    ...
# 2022-10-01   NaN            9906221.34  13.65
# 2022-11-01   NaN            9931863.43  13.65
# 2022-12-01   NaN            9956096.85  13.65
# 2023-01-01   NaN                   NaN  13.65
# 2023-02-01   NaN                   NaN  13.65
#
# [278 rows x 11 columns]

# %% [markdown]
# ###Tx. méd. mensal de juros das op. de créd. com rec. livres - PF - Crédito pessoal total

# %%
dados_completo['juros_cred_livre_pf'] = sgs.get({'juros_cred_livre_pf':25470})
dados_completo
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2000-01-01                    NaN           4083.00    1.80
# 2000-02-01                    NaN           4016.00    1.77
# 2000-03-01                    NaN           4099.00    1.75
# 2000-04-01                    NaN           4065.00    1.81
# 2000-05-01                    NaN           3931.00    1.83
# ...                           ...               ...     ...
# 2022-10-01                    NaN           7483.00    5.26
# 2022-11-01                    NaN           7721.00    5.29
# 2022-12-01                    NaN               NaN    5.22
# 2023-01-01                    NaN               NaN    5.10
# 2023-02-01                    NaN               NaN     NaN
#
#             endividamento_exhabit    cheques        imc  icc_fecomercio  ipca  \
# 2000-01-01                    NaN        NaN        NaN          100.91  0.62
# 2000-02-01                    NaN        NaN        NaN          107.34  0.13
# 2000-03-01                    NaN        NaN        NaN          100.09  0.22
# 2000-04-01                    NaN        NaN        NaN           93.93  0.42
# 2000-05-01                    NaN        NaN        NaN           89.44  0.01
# ...                           ...        ...        ...             ...   ...
# 2022-10-01                    NaN 2631856.00 1742839.00          114.23  0.59
# 2022-11-01                    NaN        NaN        NaN          116.79  0.41
# 2022-12-01                    NaN        NaN        NaN          122.84  0.62
# 2023-01-01                    NaN        NaN        NaN          125.38  0.53
# 2023-02-01                    NaN        NaN        NaN             NaN   NaN
#
#             msad  estoque_empregos_com  selic  juros_cred_livre_pf
# 2000-01-01   NaN            3385641.36  18.94                 4.80
# 2000-02-01   NaN            3397098.93  18.87                 4.85
# 2000-03-01   NaN            3425390.06  18.85                 4.47
# 2000-04-01   NaN            3436131.05  18.62                 4.42
# 2000-05-01   NaN            3444717.86  18.51                 4.35
# ...          ...                   ...    ...                  ...
# 2022-10-01   NaN            9906221.34  13.65                 2.99
# 2022-11-01   NaN            9931863.43  13.65                 2.96
# 2022-12-01   NaN            9956096.85  13.65                 2.90
# 2023-01-01   NaN                   NaN  13.65                  NaN
# 2023-02-01   NaN                   NaN  13.65                  NaN
#
# [278 rows x 12 columns]

# %% [markdown]
# ## PMC ampliado - Índice de volume de vendas - com e sem ajuste sazonal
# pmc = #ttps://apisidra.ibge.gov.br/values/t/8186/n1/all/v/11706,11707/p/all/c11046/56736/d/v11706%205,v11707%205
#
# https://sidra.ibge.gov.br/tabela/8186

# %%
#!pip install sidrapy
#import sidrapy

# %%
#t/8186/n1/all/v/11706,11707/p/all/c11046/all/d/v11706%205,v11707%205

# %%
url_sazonal = "https://sidra.ibge.gov.br/geratabela?format=xlsx&name=tabela8186.xlsx&terr=N&rank=-&query=t/8186/n1/all/v/11706/p/all/c11046/56736/d/v11706%205/l/v,p%2Bc11046,t"
url_com_ajuste = "https://sidra.ibge.gov.br/geratabela?format=xlsx&name=tabela8186.xlsx&terr=N&rank=-&query=t/8186/n1/all/v/11707/p/all/c11046/56736/d/v11707%205/l/v,p%2Bc11046,t"
df_sazonal = pd.read_excel(url_sazonal,skiprows=3)[:-1]
df_com_ajuste = pd.read_excel(url_com_ajuste,skiprows=3)[:-1]
df_com_ajuste
# Out:
#   Unnamed: 0                                       janeiro 2003  \
# 0        NaN  Índice de volume de vendas no comércio varejis...
# 1     Brasil                                              45.76
#
#                                       fevereiro 2003  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              46.93
#
#                                           março 2003  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              45.79
#
#                                           abril 2003  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              45.67
#
#                                            maio 2003  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              45.20
#
#                                           junho 2003  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              45.60
#
#                                           julho 2003  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              46.23
#
#                                          agosto 2003  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              46.48
#
#                                        setembro 2003  ...  \
# 0  Índice de volume de vendas no comércio varejis...  ...
# 1                                              47.32  ...
#
#                                           março 2022  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              97.85
#
#                                           abril 2022  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              97.48
#
#                                            maio 2022  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              98.36
#
#                                           junho 2022  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              95.99
#
#                                           julho 2022  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              95.66
#
#                                          agosto 2022  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              95.49
#
#                                        setembro 2022  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              96.77
#
#                                         outubro 2022  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              97.03
#
#                                        novembro 2022  \
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              96.55
#
#                                        dezembro 2022
# 0  Índice de volume de vendas no comércio varejis...
# 1                                              96.97
#
# [2 rows x 241 columns]

# %%
df_com_ajuste = df_com_ajuste.T
df_com_ajuste = df_com_ajuste.iloc[1:,:]
df_sazonal = df_sazonal.T
df_sazonal = df_sazonal.iloc[1:,:]
df.dropna(inplace=True)
df_pmc = pd.DataFrame()
df_pmc['pmc_com_ajuste'] = df_com_ajuste.iloc[:,1]
df_pmc['pmc'] = df_sazonal.iloc[:,1]

# %%
df_pmc
# Out:
#                pmc_com_ajuste    pmc
# janeiro 2003            45.76  44.34
# fevereiro 2003          46.93  42.70
# março 2003              45.79  42.79
# abril 2003              45.67  43.70
# maio 2003               45.20  45.61
# ...                       ...    ...
# agosto 2022             95.49  98.81
# setembro 2022           96.77  95.74
# outubro 2022            97.03  97.51
# novembro 2022           96.55 101.58
# dezembro 2022           96.97 113.10
#
# [240 rows x 2 columns]

# %%
from datetime import datetime

months = {'janeiro': 'january', 'fevereiro': 'february', 'março': 'march',
          'abril': 'april', 'maio': 'may', 'junho': 'june',
          'julho': 'july', 'agosto': 'august', 'setembro': 'september',
          'outubro': 'october', 'novembro': 'november', 'dezembro': 'december'}

lista_data = []
for date in df_pmc.index:
    date_components = date.split(' ')
    formatted_month = months[date_components[0].lower()].capitalize()
    formatted_date = f"{formatted_month} {date_components[1]}"
    date_object = datetime.strptime(formatted_date, '%B %Y')
    lista_data.append(date_object.strftime('%Y-%m-%d'))
df_pmc.index = lista_data

# %%
df_pmc.index = pd.to_datetime(df_pmc.index)

# %%
df_pmc
# Out:
#            pmc_com_ajuste    pmc
# 2003-01-01          45.76  44.34
# 2003-02-01          46.93  42.70
# 2003-03-01          45.79  42.79
# 2003-04-01          45.67  43.70
# 2003-05-01          45.20  45.61
# ...                   ...    ...
# 2022-08-01          95.49  98.81
# 2022-09-01          96.77  95.74
# 2022-10-01          97.03  97.51
# 2022-11-01          96.55 101.58
# 2022-12-01          96.97 113.10
#
# [240 rows x 2 columns]

# %%
df_pmc.index
# Out:
# DatetimeIndex(['2003-01-01', '2003-02-01', '2003-03-01', '2003-04-01',
#                '2003-05-01', '2003-06-01', '2003-07-01', '2003-08-01',
#                '2003-09-01', '2003-10-01',
#                ...
#                '2022-03-01', '2022-04-01', '2022-05-01', '2022-06-01',
#                '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01',
#                '2022-11-01', '2022-12-01'],
#               dtype='datetime64[ns]', length=240, freq=None)

# %% [markdown]
# ##Importando dados de expectativa de PIB Total (Focus/BCB)
# https://wilsonfreitas.github.io/python-bcb/expectativas.html#bcb.Expectativas
#
# https://analisemacro.com.br/economia/indicadores/como-coletar-dados-do-boletim-focus-com-o-python/

# %%
# !pip install python-bcb

from bcb import Expectativas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: python-bcb in /usr/local/lib/python3.8/dist-packages (0.1.8)
# Requirement already satisfied: httpx<0.24.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from python-bcb) (0.23.3)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.8/dist-packages (from python-bcb) (2.28.2)
# Requirement already satisfied: lxml<5.0.0,>=4.9.1 in /usr/local/lib/python3.8/dist-packages (from python-bcb) (4.9.2)
# Requirement already satisfied: pandas<2.0.0,>=1.4.4 in /usr/local/lib/python3.8/dist-packages (from python-bcb) (1.5.3)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /usr/local/lib/python3.8/dist-packages (from httpx<0.24.0,>=0.23.0->python-bcb) (0.16.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from httpx<0.24.0,>=0.23.0->python-bcb) (2022.12.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.8/dist-packages (from httpx<0.24.0,>=0.23.0->python-bcb) (1.3.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /usr/local/lib/python3.8/dist-packages (from httpx<0.24.0,>=0.23.0->python-bcb) (1.5.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.4.4->python-bcb) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.4.4->python-bcb) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.4.4->python-bcb) (1.21.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.28.1->python-bcb) (2.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.28.1->python-bcb) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.28.1->python-bcb) (1.24.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.8/dist-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->python-bcb) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.8/dist-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->python-bcb) (3.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.4.4->python-bcb) (1.15.0)

# %% [markdown]
# ExpectativasMercadoTop5Anuais: Expectativas de mercado anuais para os indicadores do Top 5
#
# ExpectativasMercadoInstituicoes: Expectativas de mercado informadas pelas instituições credenciadas
#
# ExpectativaMercadoMensais: Expectativas de Mercado Mensais
#
# ExpectativasMercadoInflacao12Meses: Expectativas de mercado para inflação nos próximos 12 meses
#
# ExpectativasMercadoTop5Mensais: Expectativas de mercado mensais para os indicadores do Top 5
#
# ExpectativasMercadoTrimestrais: Expectativas de Mercado Trimestrais
#
# ExpectativasMercadoAnuais: Expectativas de Mercado Anuais

# %%
"""# End point
em = Expectativas()
ep = em.get_endpoint('ExpectativasMercadoAnuais')

# Dados do IPCA

ipca_expec = (ep.query()
 .filter(ep.Indicador == 'IPCA')
 .filter(ep.Data >= data_inicio)
 .filter(ep.baseCalculo == '0')
 .select(ep.Indicador, ep.Data, ep.Media, ep.Mediana, ep.DataReferencia)
 .collect()
  )
# Formata a coluna de Data para formato datetime

ipca_expec.index = pd.to_datetime(ipca_expec['Data'], format = '%Y-%m-%d')
ipca_expec"""
# Out:
# "# End point\nem = Expectativas()\nep = em.get_endpoint('ExpectativasMercadoAnuais')\n\n# Dados do IPCA\n\nipca_expec = (ep.query()\n .filter(ep.Indicador == 'IPCA')\n .filter(ep.Data >= data_inicio)\n .filter(ep.baseCalculo == '0')\n .select(ep.Indicador, ep.Data, ep.Media, ep.Mediana, ep.DataReferencia)\n .collect()\n  )\n# Formata a coluna de Data para formato datetime\n\nipca_expec.index = pd.to_datetime(ipca_expec['Data'], format = '%Y-%m-%d')\nipca_expec"

# %%
# End point
em = Expectativas()
ep = em.get_endpoint('ExpectativasMercadoTrimestrais')

# %%
#Pesquisando a serie
#pib = ep.query().limit(3000000).collect()

# %%
# End point
em = Expectativas()
ep = em.get_endpoint('ExpectativasMercadoTrimestrais')

# Dados do IPCA
pib_expec = (ep.query()
 .filter(ep.Indicador == 'PIB Total')
 .filter(ep.baseCalculo == '0')
 .select(ep.Indicador, ep.Data, ep.Media, ep.Mediana, ep.DataReferencia)
 .collect()
  )

# %%
pib_expec = pib_expec.loc[:,['Data','Mediana']]

# %%
pib_expec.index= pd.to_datetime(pib_expec['Data'])
pib_expec.drop('Data',axis=1,inplace=True)

# %%
pib_expec = pib_expec.resample('MS').median()

# %% [markdown]
# ##Juntando os dados

# %%
dados = dados_completo.copy()

# %%
dados['icf'] = df_icf['ICF']
dados['atividade'] = df_atividade['Geral']
dados['credito'] = df_credito['Total']
dados['Familias Endividadas (% do total de famílias)'] = df_peic['Familias Endividadas (% do total de famílias)']
dados['falencias'] = df_falencia['Comércio']
dados['nascimento'] = df_nascimento['Comércio']
dados['damanda_credito'] = df_credito['Total']
dados['poupanca'] = df_poupanca['poupanca']
dados['icva'] = df_icva['Deflacionado - Com Ajuste Calendário']
dados['pmc'] = df_pmc['pmc']
dados['pib_expec'] = pib_expec['Mediana']

# %%
#Primeira data do pmc
dados = dados[dados['pmc'].index >= '2003-01-01']

# %% [markdown]
# #Tratando os dados

# %%
dados
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2003-01-01                    NaN           4182.00    3.53
# 2003-02-01                    NaN           4153.00    3.56
# 2003-03-01                    NaN           4221.00    3.35
# 2003-04-01                    NaN           3948.00    2.89
# 2003-05-01                    NaN           3938.00    2.97
# ...                           ...               ...     ...
# 2022-10-01                    NaN           7483.00    5.26
# 2022-11-01                    NaN           7721.00    5.29
# 2022-12-01                    NaN               NaN    5.22
# 2023-01-01                    NaN               NaN    5.10
# 2023-02-01                    NaN               NaN     NaN
#
#             endividamento_exhabit    cheques        imc  icc_fecomercio  ipca  \
# 2003-01-01                    NaN 1826505.00        NaN          102.97  2.25
# 2003-02-01                    NaN 1775727.00        NaN          103.53  1.57
# 2003-03-01                    NaN 1781840.00        NaN          101.89  1.23
# 2003-04-01                    NaN 1797816.00        NaN          107.66  0.97
# 2003-05-01                    NaN 1762238.00        NaN          112.04  0.61
# ...                           ...        ...        ...             ...   ...
# 2022-10-01                    NaN 2631856.00 1742839.00          114.23  0.59
# 2022-11-01                    NaN        NaN        NaN          116.79  0.41
# 2022-12-01                    NaN        NaN        NaN          122.84  0.62
# 2023-01-01                    NaN        NaN        NaN          125.38  0.53
# 2023-02-01                    NaN        NaN        NaN             NaN   NaN
#
#             msad  estoque_empregos_com  ...  atividade  credito  \
# 2003-01-01   NaN            4045873.70  ...      46.35      NaN
# 2003-02-01   NaN            4068558.78  ...      49.05      NaN
# 2003-03-01   NaN            4082585.40  ...      41.96      NaN
# 2003-04-01   NaN            4099204.40  ...      46.80      NaN
# 2003-05-01   NaN            4115164.19  ...      45.94      NaN
# ...          ...                   ...  ...        ...      ...
# 2022-10-01   NaN            9906221.34  ...      78.54    91.33
# 2022-11-01   NaN            9931863.43  ...      80.28    87.86
# 2022-12-01   NaN            9956096.85  ...      81.07    77.28
# 2023-01-01   NaN                   NaN  ...        NaN      NaN
# 2023-02-01   NaN                   NaN  ...        NaN      NaN
#
#             Familias Endividadas (% do total de famílias)  falencias  \
# 2003-01-01                                            NaN       0.00
# 2003-02-01                                            NaN       0.00
# 2003-03-01                                            NaN       0.00
# 2003-04-01                                            NaN       0.00
# 2003-05-01                                            NaN       0.00
# ...                                                   ...        ...
# 2022-10-01                                           0.79      10.00
# 2022-11-01                                           0.79      24.00
# 2022-12-01                                           0.78      10.00
# 2023-01-01                                           0.78        NaN
# 2023-02-01                                            NaN        NaN
#
#             nascimento damanda_credito  poupanca  icva    pmc  pib_expec
# 2003-01-01         NaN             NaN      9.41   NaN  44.34       1.90
# 2003-02-01         NaN             NaN      9.25   NaN  42.70       1.95
# 2003-03-01         NaN             NaN      9.05   NaN  42.79       2.00
# 2003-04-01         NaN             NaN      8.87   NaN  43.70       1.90
# 2003-05-01         NaN             NaN      8.76   NaN  45.61       1.90
# ...                ...             ...       ...   ...    ...        ...
# 2022-10-01    65679.00           91.33     10.19   NaN  97.51       1.23
# 2022-11-01         NaN           87.86     10.11   NaN 101.58       1.25
# 2022-12-01         NaN           77.28     10.16   NaN 113.10       1.12
# 2023-01-01         NaN             NaN       NaN   NaN    NaN       1.23
# 2023-02-01         NaN             NaN       NaN   NaN    NaN       1.22
#
# [242 rows x 23 columns]

# %%
dados.isnull().sum()
# Out:
# comprometimento_renda                             44
# cons_energia_com                                   3
# cambio                                             1
# endividamento_exhabit                             42
# cheques                                            4
# imc                                               16
# icc_fecomercio                                     1
# ipca                                               1
# msad                                              26
# estoque_empregos_com                               2
# selic                                              0
# juros_cred_livre_pf                                2
# icf                                              229
# atividade                                          2
# credito                                           50
# Familias Endividadas (% do total de famílias)    229
# falencias                                          2
# nascimento                                       168
# damanda_credito                                   50
# poupanca                                           2
# icva                                             137
# pmc                                                2
# pib_expec                                          0
# dtype: int64

# %% [markdown]
# ##Deflacionar a Massa Salarial Ampliada
#
# https://pypi.org/project/deflateBR/

# %%
# !pip install deflateBR
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deflateBR in /usr/local/lib/python3.8/dist-packages (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from deflateBR) (1.21.6)
# Requirement already satisfied: datetime in /usr/local/lib/python3.8/dist-packages (from deflateBR) (5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from deflateBR) (2.28.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from deflateBR) (1.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from deflateBR) (4.64.1)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.8/dist-packages (from datetime->deflateBR) (5.5.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from datetime->deflateBR) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas->deflateBR) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->deflateBR) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->deflateBR) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests->deflateBR) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->deflateBR) (2.10)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas->deflateBR) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from zope.interface->datetime->deflateBR) (57.4.0)

# %%
import deflatebr as dbr

# %%
#Nao deu pra colocar a data de hoje, tem que ser reduzido alguns dias
data_inicio = datetime.today() - timedelta(days=60)
data_inicio= data_inicio.strftime('%Y-%m')

# %%
lista_msad = dbr.deflate(nominal_values=dados.msad, nominal_dates=dados.index, 
            real_date=data_inicio,index='inpc')

# %%
dados['msad_deflacionado'] = lista_msad

# %%
dados.drop('msad',axis=1,inplace=True)

# %%
dados
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2003-01-01                    NaN           4182.00    3.53
# 2003-02-01                    NaN           4153.00    3.56
# 2003-03-01                    NaN           4221.00    3.35
# 2003-04-01                    NaN           3948.00    2.89
# 2003-05-01                    NaN           3938.00    2.97
# ...                           ...               ...     ...
# 2022-10-01                    NaN           7483.00    5.26
# 2022-11-01                    NaN           7721.00    5.29
# 2022-12-01                    NaN               NaN    5.22
# 2023-01-01                    NaN               NaN    5.10
# 2023-02-01                    NaN               NaN     NaN
#
#             endividamento_exhabit    cheques        imc  icc_fecomercio  ipca  \
# 2003-01-01                    NaN 1826505.00        NaN          102.97  2.25
# 2003-02-01                    NaN 1775727.00        NaN          103.53  1.57
# 2003-03-01                    NaN 1781840.00        NaN          101.89  1.23
# 2003-04-01                    NaN 1797816.00        NaN          107.66  0.97
# 2003-05-01                    NaN 1762238.00        NaN          112.04  0.61
# ...                           ...        ...        ...             ...   ...
# 2022-10-01                    NaN 2631856.00 1742839.00          114.23  0.59
# 2022-11-01                    NaN        NaN        NaN          116.79  0.41
# 2022-12-01                    NaN        NaN        NaN          122.84  0.62
# 2023-01-01                    NaN        NaN        NaN          125.38  0.53
# 2023-02-01                    NaN        NaN        NaN             NaN   NaN
#
#             estoque_empregos_com  selic  ...  credito  \
# 2003-01-01            4045873.70  25.06  ...      NaN
# 2003-02-01            4068558.78  25.68  ...      NaN
# 2003-03-01            4082585.40  26.32  ...      NaN
# 2003-04-01            4099204.40  26.32  ...      NaN
# 2003-05-01            4115164.19  26.31  ...      NaN
# ...                          ...    ...  ...      ...
# 2022-10-01            9906221.34  13.65  ...    91.33
# 2022-11-01            9931863.43  13.65  ...    87.86
# 2022-12-01            9956096.85  13.65  ...    77.28
# 2023-01-01                   NaN  13.65  ...      NaN
# 2023-02-01                   NaN  13.65  ...      NaN
#
#             Familias Endividadas (% do total de famílias)  falencias  \
# 2003-01-01                                            NaN       0.00
# 2003-02-01                                            NaN       0.00
# 2003-03-01                                            NaN       0.00
# 2003-04-01                                            NaN       0.00
# 2003-05-01                                            NaN       0.00
# ...                                                   ...        ...
# 2022-10-01                                           0.79      10.00
# 2022-11-01                                           0.79      24.00
# 2022-12-01                                           0.78      10.00
# 2023-01-01                                           0.78        NaN
# 2023-02-01                                            NaN        NaN
#
#             nascimento damanda_credito  poupanca  icva    pmc  pib_expec  \
# 2003-01-01         NaN             NaN      9.41   NaN  44.34       1.90
# 2003-02-01         NaN             NaN      9.25   NaN  42.70       1.95
# 2003-03-01         NaN             NaN      9.05   NaN  42.79       2.00
# 2003-04-01         NaN             NaN      8.87   NaN  43.70       1.90
# 2003-05-01         NaN             NaN      8.76   NaN  45.61       1.90
# ...                ...             ...       ...   ...    ...        ...
# 2022-10-01    65679.00           91.33     10.19   NaN  97.51       1.23
# 2022-11-01         NaN           87.86     10.11   NaN 101.58       1.25
# 2022-12-01         NaN           77.28     10.16   NaN 113.10       1.12
# 2023-01-01         NaN             NaN       NaN   NaN    NaN       1.23
# 2023-02-01         NaN             NaN       NaN   NaN    NaN       1.22
#
#            msad_deflacionado
# 2003-01-01               NaN
# 2003-02-01               NaN
# 2003-03-01               NaN
# 2003-04-01               NaN
# 2003-05-01               NaN
# ...                      ...
# 2022-10-01               NaN
# 2022-11-01               NaN
# 2022-12-01               NaN
# 2023-01-01               NaN
# 2023-02-01               NaN
#
# [242 rows x 23 columns]

# %% [markdown]
# ##Criando dummy Covid para as 2020-04-01 e 2020-05-01

# %%
dados['dummy_covid'] = np.where((dados.index >= pd.to_datetime('2020-04-01')) & (dados.index <= pd.to_datetime('2020-05-01')), 1,0)
dados
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2003-01-01                    NaN           4182.00    3.53
# 2003-02-01                    NaN           4153.00    3.56
# 2003-03-01                    NaN           4221.00    3.35
# 2003-04-01                    NaN           3948.00    2.89
# 2003-05-01                    NaN           3938.00    2.97
# ...                           ...               ...     ...
# 2022-10-01                    NaN           7483.00    5.26
# 2022-11-01                    NaN           7721.00    5.29
# 2022-12-01                    NaN               NaN    5.22
# 2023-01-01                    NaN               NaN    5.10
# 2023-02-01                    NaN               NaN     NaN
#
#             endividamento_exhabit    cheques        imc  icc_fecomercio  ipca  \
# 2003-01-01                    NaN 1826505.00        NaN          102.97  2.25
# 2003-02-01                    NaN 1775727.00        NaN          103.53  1.57
# 2003-03-01                    NaN 1781840.00        NaN          101.89  1.23
# 2003-04-01                    NaN 1797816.00        NaN          107.66  0.97
# 2003-05-01                    NaN 1762238.00        NaN          112.04  0.61
# ...                           ...        ...        ...             ...   ...
# 2022-10-01                    NaN 2631856.00 1742839.00          114.23  0.59
# 2022-11-01                    NaN        NaN        NaN          116.79  0.41
# 2022-12-01                    NaN        NaN        NaN          122.84  0.62
# 2023-01-01                    NaN        NaN        NaN          125.38  0.53
# 2023-02-01                    NaN        NaN        NaN             NaN   NaN
#
#             estoque_empregos_com  selic  ...  \
# 2003-01-01            4045873.70  25.06  ...
# 2003-02-01            4068558.78  25.68  ...
# 2003-03-01            4082585.40  26.32  ...
# 2003-04-01            4099204.40  26.32  ...
# 2003-05-01            4115164.19  26.31  ...
# ...                          ...    ...  ...
# 2022-10-01            9906221.34  13.65  ...
# 2022-11-01            9931863.43  13.65  ...
# 2022-12-01            9956096.85  13.65  ...
# 2023-01-01                   NaN  13.65  ...
# 2023-02-01                   NaN  13.65  ...
#
#             Familias Endividadas (% do total de famílias)  falencias  \
# 2003-01-01                                            NaN       0.00
# 2003-02-01                                            NaN       0.00
# 2003-03-01                                            NaN       0.00
# 2003-04-01                                            NaN       0.00
# 2003-05-01                                            NaN       0.00
# ...                                                   ...        ...
# 2022-10-01                                           0.79      10.00
# 2022-11-01                                           0.79      24.00
# 2022-12-01                                           0.78      10.00
# 2023-01-01                                           0.78        NaN
# 2023-02-01                                            NaN        NaN
#
#             nascimento  damanda_credito poupanca  icva    pmc  pib_expec  \
# 2003-01-01         NaN              NaN     9.41   NaN  44.34       1.90
# 2003-02-01         NaN              NaN     9.25   NaN  42.70       1.95
# 2003-03-01         NaN              NaN     9.05   NaN  42.79       2.00
# 2003-04-01         NaN              NaN     8.87   NaN  43.70       1.90
# 2003-05-01         NaN              NaN     8.76   NaN  45.61       1.90
# ...                ...              ...      ...   ...    ...        ...
# 2022-10-01    65679.00            91.33    10.19   NaN  97.51       1.23
# 2022-11-01         NaN            87.86    10.11   NaN 101.58       1.25
# 2022-12-01         NaN            77.28    10.16   NaN 113.10       1.12
# 2023-01-01         NaN              NaN      NaN   NaN    NaN       1.23
# 2023-02-01         NaN              NaN      NaN   NaN    NaN       1.22
#
#             msad_deflacionado dummy_covid
# 2003-01-01                NaN           0
# 2003-02-01                NaN           0
# 2003-03-01                NaN           0
# 2003-04-01                NaN           0
# 2003-05-01                NaN           0
# ...                       ...         ...
# 2022-10-01                NaN           0
# 2022-11-01                NaN           0
# 2022-12-01                NaN           0
# 2023-01-01                NaN           0
# 2023-02-01                NaN           0
#
# [242 rows x 24 columns]

# %% [markdown]
# ##Fazendo Backcasting nos valores faltantes com arvores de decisao

# %%
dados_interpolacao = dados.copy()

# %%
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %%
np.random.seed(0)

dados_bac = dados.copy()
for i in dados.columns:
    dados_interpolacao = dados.copy()

    dados_interpolacao = dados_interpolacao.loc[:dados_interpolacao[i].last_valid_index()]


    # Separate values not NaN and NaN in two different dataframes
    treino_interpolacao = dados_interpolacao[dados_interpolacao[i].notnull()]
    predicao_interpolacao = dados_interpolacao[dados_interpolacao[i].isnull()]
  
    # Create Y_treino column and remove from treino_interpolacao
    Y_treino = treino_interpolacao[i]
    treino_interpolacao = treino_interpolacao.drop(i,axis=1)

    predicao_interpolacao = predicao_interpolacao.drop(i,axis=1)
    
    # Remove columns with more than 10 NaN values
    predicao_interpolacao = predicao_interpolacao.dropna(thresh=len(predicao_interpolacao) - 4, axis=1)

    Y_treino = Y_treino[Y_treino.index.isin(treino_interpolacao.index)]

    treino_interpolacao = treino_interpolacao.loc[:, predicao_interpolacao.columns]

   # Fill NaN values in remaining columns with the mean
    treino_interpolacao = treino_interpolacao.fillna(treino_interpolacao.mean())
    predicao_interpolacao = predicao_interpolacao.fillna(predicao_interpolacao.mean())
   # Filter prediction dataframe to include only columns present in training dataframe
   # Create the model
    model = XGBRegressor(random_state=0)
   
   # Train the model
    model.fit(treino_interpolacao.values,Y_treino.values.reshape(-1,1))
    predicao = model.predict(predicao_interpolacao.values)
    interpolados = pd.DataFrame(predicao,index=predicao_interpolacao.index)
    interpolados.columns = [i]
    dados_bac.fillna(interpolados,inplace=True)
# Out:
# [16:08:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:08:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
for i in dados.columns:
  plt.plot(dados_bac[i])
  plt.plot(dados[i])
  plt.title(i)
  plt.show()

# %% [markdown]
# ##Estacionaridade
# A TS é dita estacionária se as suas propriedades estatísticas, tais como a média e variância permanecem constantes ao longo do tempo. Mas por que isso é importante? A maioria dos modelos TS trabalha com o pressuposto de que a TS é estacionária. Intuitivamente, podemos entender que se uma TS tem um comportamento particular ao longo de um tempo, há uma probabilidade muito elevada de que seguirá o mesmo comportamento no futuro. Além disso, as teorias relacionadas com séries estacionárias são mais maduras e mais fáceis de implementar, em comparação com séries não-estacionárias.
#
# https://www.vooo.pro/insights/guia-completo-para-criar-time-series-com-codigo-em-python/

# %%
def plotar(dados):
  for i in range(len(dados.columns)):
    fig, ax = plt.subplots(dpi=120)
    ax.plot(dados.iloc[:,i],label=dados.columns[i])
    plt.legend()
    plt.show()

# %%
plotar(dados_bac)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ###Teste de estacionaridade Dickey-Fuller
# Dickey-Fuller teste: esse é um dos testes estatísticos para verificar Estacionaridade. Aqui, a hipótese nula é que o TS é não-estacionária. Os resultados do teste são compostos por uma estatística de teste e alguns valores críticos para os níveis de confiança da diferença. Se o ‘teste estatístico’ é menor do que o “valor crítico”, podemos rejeitar a hipótese nula e dizer que a série é estacionária. Consulte este artigo para obter detalhes.

# %%
def test_kpss_adf(dados):
  #https://www.statsmodels.org/dev/examples/notebooks/generated/stationarity_detrending_adf_kpss.html
  def kpss_test(timeseries):
    """
    O KPSS é outro teste para verificar a estacionaridade de uma série temporal. As hipóteses nula e alternativa para o teste KPSS são opostas às do teste ADF.

    Hipótese Nula: O processo é estacionário de tendência.

    Hipótese Alternativa: A série tem raiz unitária (a série não é estacionária).

    Uma função é criada para realizar o teste KPSS em uma série temporal.
    """
    #print("Results of KPSS Test:")
    kpsstest = kpss(timeseries, regression="c", nlags="auto")
    kpss_output = pd.Series(
      kpsstest[0:3], index=["Test Statistic", "p-value", "Lags Used"]
    )
    for key, value in kpsstest[3].items():
        kpss_output["Critical Value (%s)" % key] = value
    return kpss_output

  def adf_test(timeseries):

    """
    O teste ADF é usado para determinar a presença de raiz unitária na série e, portanto, ajuda a entender se a série é estacionária ou não. As hipóteses nula e 
    alternativa deste teste são:
    Hipótese Nula: A série tem raiz unitária.
    Hipótese alternativa: A série não tem raiz unitária.
    Se a hipótese nula não for rejeitada, este teste pode fornecer evidências de que a série é não estacionária.
   Uma função é criada para realizar o teste ADF em uma série temporal.
    """
    #print("Results of Dickey-Fuller Test:")
    dftest = adfuller(timeseries, autolag="AIC")
    dfoutput = pd.Series(
      dftest[0:4],
      index=[
            "Test Statistic",
            "p-value",
            "#Lags Used",
            "Number of Observations Used",
        ],
    )
    for key, value in dftest[4].items():
      dfoutput["Critical Value (%s)" % key] = value
    return dfoutput


  test_est = pd.DataFrame(index=dados.columns,columns = ['Teste_kpss', 'Estacionaria_ou_nâo_kpss','Teste_adf','Estacionaria_ou_nâo_adf'])
  for k in dados.columns:
    tes_kpss = kpss_test(dados[k].dropna())
    test_est.loc[k,test_est.columns[0]] = tes_kpss[1]
    tes_adf = adf_test(dados[k].dropna())
    test_est.loc[k,test_est.columns[2]] = tes_adf[1]
  test_est['Estacionaria_ou_nâo_kpss']=np.where(test_est['Teste_kpss'] >= 0.05,'Estacionaria','Nâo estacionaria')
  test_est['Estacionaria_ou_nâo_adf']=np.where(test_est['Teste_adf'] <= 0.05,'Estacionaria','Nâo estacionaria')
  return test_est

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    from statsmodels.tsa.stattools import adfuller
    import pandas as pd
    import matplotlib.pylab as plt
    import seaborn as sns
    import numpy as np
    for i in range(len(timeseries.columns)):
     #Determing rolling statistics
      rolmean = pd.Series(timeseries.iloc[:,i]).rolling(window=12).mean().dropna()
      rolstd = pd.Series(timeseries.iloc[:,i]).rolling(window=12).std().dropna()

      #Plot rolling statistics:
      if type(timeseries[dados.columns[i]][0]) != str:
        orig = plt.plot(timeseries.iloc[:,i], color='blue',label='Original')
        mean = plt.plot(rolmean, color='red', label='Rolling Mean')
        std = plt.plot(rolstd, color='black', label = 'Rolling Std')
        plt.legend(loc='best')
        plt.title(f'Rolling Mean & Standard Deviation na variavel {dados.columns[i]}')
        plt.show(block=False)
    
        #Perform Dickey-Fuller test:
        print (f'Results of Dickey-Fuller Test:Coluna {dados.columns[i]}')
        dftest = adfuller(timeseries.iloc[:,i].dropna(), autolag='AIC')
        dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
        for key,value in dftest[4].items():
          dfoutput['Critical Value (%s)'%key] = value
        print(dfoutput)
      else:
        try:
          timeseries.iloc[:,i] = timeseries.iloc[:,i].astype(int)
          orig = plt.plot(timeseries.iloc[:,i], color='blue',label='Original')
          mean = plt.plot(rolmean, color='red', label='Rolling Mean')
          std = plt.plot(rolstd, color='black', label = 'Rolling Std')
          plt.legend(loc='best')
          plt.title(f'Rolling Mean & Standard Deviation na variavel {dados.columns[i]}')
          plt.show(block=False)
    
          #Perform Dickey-Fuller test:
          print (f'Results of Dickey-Fuller Test:Coluna {dados.columns[i]}')
          dftest = adfuller(timeseries.iloc[:,i].dropna(), autolag='AIC')
          dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
          for key,value in dftest[4].items():
           dfoutput['Critical Value (%s)'%key] = value
          print(dfoutput)
        except:
          timeseries.iloc[:,i] = timeseries.iloc[:,i].astype(float)
          orig = plt.plot(timeseries.iloc[:,i], color='blue',label='Original')
          mean = plt.plot(rolmean, color='red', label='Rolling Mean')
          std = plt.plot(rolstd, color='black', label = 'Rolling Std')
          plt.legend(loc='best')
          plt.title(f'Rolling Mean & Standard Deviation na variavel {dados.columns[i]}')
          plt.show(block=False)
    
          #Perform Dickey-Fuller test:
          print (f'Results of Dickey-Fuller Test:Coluna {dados.columns[i]}')
          dftest = adfuller(timeseries.iloc[:,i].dropna(), autolag='AIC')
          dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
          for key,value in dftest[4].items():
           dfoutput['Critical Value (%s)'%key] = value
          print(dfoutput)
        
    return test_kpss_adf(timeseries)

# %%
test = test_stationarity(dados_bac)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
test
# Out:
#                                               Teste_kpss  \
# comprometimento_renda                               0.01
# cons_energia_com                                    0.01
# cambio                                              0.01
# endividamento_exhabit                               0.01
# cheques                                             0.06
# imc                                                 0.01
# icc_fecomercio                                      0.01
# ipca                                                0.10
# estoque_empregos_com                                0.01
# selic                                               0.01
# juros_cred_livre_pf                                 0.01
# icf                                                 0.02
# atividade                                           0.01
# credito                                             0.01
# Familias Endividadas (% do total de famílias)       0.10
# falencias                                           0.02
# nascimento                                          0.01
# damanda_credito                                     0.01
# poupanca                                            0.01
# icva                                                0.01
# pmc                                                 0.01
# pib_expec                                           0.01
# msad_deflacionado                                   0.01
# dummy_covid                                         0.10
#
#                                               Estacionaria_ou_nâo_kpss  \
# comprometimento_renda                                 Nâo estacionaria
# cons_energia_com                                      Nâo estacionaria
# cambio                                                Nâo estacionaria
# endividamento_exhabit                                 Nâo estacionaria
# cheques                                                   Estacionaria
# imc                                                   Nâo estacionaria
# icc_fecomercio                                        Nâo estacionaria
# ipca                                                      Estacionaria
# estoque_empregos_com                                  Nâo estacionaria
# selic                                                 Nâo estacionaria
# juros_cred_livre_pf                                   Nâo estacionaria
# icf                                                   Nâo estacionaria
# atividade                                             Nâo estacionaria
# credito                                               Nâo estacionaria
# Familias Endividadas (% do total de famílias)             Estacionaria
# falencias                                             Nâo estacionaria
# nascimento                                            Nâo estacionaria
# damanda_credito                                       Nâo estacionaria
# poupanca                                              Nâo estacionaria
# icva                                                  Nâo estacionaria
# pmc                                                   Nâo estacionaria
# pib_expec                                             Nâo estacionaria
# msad_deflacionado                                     Nâo estacionaria
# dummy_covid                                               Estacionaria
#
#                                               Teste_adf  \
# comprometimento_renda                              0.39
# cons_energia_com                                   0.46
# cambio                                             0.94
# endividamento_exhabit                              0.63
# cheques                                            0.07
# imc                                                0.19
# icc_fecomercio                                     0.18
# ipca                                               0.00
# estoque_empregos_com                               0.27
# selic                                              0.01
# juros_cred_livre_pf                                0.01
# icf                                                0.03
# atividade                                          0.18
# credito                                            0.69
# Familias Endividadas (% do total de famílias)      0.11
# falencias                                          0.01
# nascimento                                         0.96
# damanda_credito                                    0.69
# poupanca                                           0.49
# icva                                               0.25
# pmc                                                0.30
# pib_expec                                          0.10
# msad_deflacionado                                  0.30
# dummy_covid                                        0.00
#
#                                               Estacionaria_ou_nâo_adf
# comprometimento_renda                                Nâo estacionaria
# cons_energia_com                                     Nâo estacionaria
# cambio                                               Nâo estacionaria
# endividamento_exhabit                                Nâo estacionaria
# cheques                                              Nâo estacionaria
# imc                                                  Nâo estacionaria
# icc_fecomercio                                       Nâo estacionaria
# ipca                                                     Estacionaria
# estoque_empregos_com                                 Nâo estacionaria
# selic                                                    Estacionaria
# juros_cred_livre_pf                                      Estacionaria
# icf                                                      Estacionaria
# atividade                                            Nâo estacionaria
# credito                                              Nâo estacionaria
# Familias Endividadas (% do total de famílias)        Nâo estacionaria
# falencias                                                Estacionaria
# nascimento                                           Nâo estacionaria
# damanda_credito                                      Nâo estacionaria
# poupanca                                             Nâo estacionaria
# icva                                                 Nâo estacionaria
# pmc                                                  Nâo estacionaria
# pib_expec                                            Nâo estacionaria
# msad_deflacionado                                    Nâo estacionaria
# dummy_covid                                              Estacionaria

# %% [markdown]
# ###Verificando a diferenca de estacionaridade
# #http://alkaline-ml.com/pmdarima/1.5.1/modules/generated/pmdarima.arima.ndiffs.html

# %%
from pmdarima import arima

# %%
def report_ndiffs (dados,test=['kpss', 'adf', 'pp'],alpha=0.05):
  dat_ndifis = pd.DataFrame(index=dados.columns)
  for i in test:
    dat_n = []
    for j in dados.columns:
      dat_n.append(arima.ndiffs(dados[j].dropna(),alpha,test=i))
    dat_ndifis[i] = dat_n
  result = []
  for k in range(len(dat_ndifis)):
    result.append(np.where(dat_ndifis.iloc[k,0]==dat_ndifis.iloc[k,1],dat_ndifis.iloc[k,0],
         np.where(dat_ndifis.iloc[k,1]==dat_ndifis.iloc[k,2],dat_ndifis.iloc[k,1],
                  np.where(dat_ndifis.iloc[k,0]==dat_ndifis.iloc[k,2],dat_ndifis.iloc[k,2],''))))
  dat_ndifis['Ndifis'] = result
  dat_ndifis.sort_values(by='Ndifis',ascending=False,inplace=True)
  dat_ndifis['Ndifis'] = dat_ndifis['Ndifis'].astype(int)
  return dat_ndifis

# %%
n_difis = report_ndiffs(dados_bac)
n_difis
# Out:
#                                                kpss  adf  pp  Ndifis
# comprometimento_renda                             1    1   1       1
# cons_energia_com                                  1    1   0       1
# msad_deflacionado                                 1    1   1       1
# pib_expec                                         1    1   1       1
# pmc                                               1    1   0       1
# icva                                              1    1   1       1
# poupanca                                          1    1   1       1
# damanda_credito                                   1    1   0       1
# nascimento                                        1    1   0       1
# Familias Endividadas (% do total de famílias)     0    1   1       1
# credito                                           1    1   0       1
# atividade                                         1    1   1       1
# icf                                               1    1   0       1
# juros_cred_livre_pf                               1    1   1       1
# selic                                             1    1   1       1
# estoque_empregos_com                              2    1   1       1
# icc_fecomercio                                    1    1   1       1
# cheques                                           1    1   1       1
# endividamento_exhabit                             1    2   1       1
# cambio                                            1    1   1       1
# falencias                                         1    0   0       0
# ipca                                              0    0   0       0
# imc                                               1    0   0       0
# dummy_covid                                       0    0   0       0

# %% [markdown]
# ###Ajustando dados nao estacionarios metodo de diferenciacao
#
# https://www.youtube.com/watch?v=JuG8hwVK5uQ
#
# Modelagem de séries temporais frequentemente exige a aplicação de transformações nas variáveis, tal como a bem conhecida primeira diferença. Formalmente, podemos descrever essa transformação como:
#
#
# Ou seja, dado uma série temporal regularmente espaçada, subtraímos do valor em t o valor anterior (t-1), obtendo a série dita "na primeira diferença" ou "nas diferenças".
#
# A mudança de nível da série geralmente contorna diversas características "não desejadas" pelo analista como tendência, sazonalidade, etc., mas dificulta a interpretação dos valores - especialmente quando pretende-se comunicá-los para públicos não técnicos. Para este objetivo é de grande utilidade saber como diferenciar uma série temporal e, sobretudo, também como reverter a transformação.

# %%
list(range(1,n_difis['Ndifis']['pmc']+1))
# Out:
# [1]

# %%
"""
def corrigindo_nao_estacionaridade(base,n_difis,valor_predicao):
  dados_est = base.copy()
  for i in n_difis[n_difis['Ndifis'] >= 1].index:
    if i == valor_predicao:
      dados_est[i] = dados_est[i]
    else:
      dados_est[i] = dados_est[i].diff(periods=n_difis[n_difis.index.isin([i])]['Ndifis'])
  return dados_est"""
# Out:
# "\ndef corrigindo_nao_estacionaridade(base,n_difis,valor_predicao):\n  dados_est = base.copy()\n  for i in n_difis[n_difis['Ndifis'] >= 1].index:\n    if i == valor_predicao:\n      dados_est[i] = dados_est[i]\n    else:\n      dados_est[i] = dados_est[i].diff(periods=n_difis[n_difis.index.isin([i])]['Ndifis'])\n  return dados_est"

# %%
def corrigindo_nao_estacionaridade(base,n_difis,valor_predicao):
  dados_est = base.copy()
  for i in n_difis[n_difis['Ndifis'] >= 1].index:
    if i == valor_predicao:
      dados_est[i] = dados_est[i]
    else:
      j = 0
      while j < n_difis['Ndifis'][i]:
        dados_est[i] = dados_est[i].diff(periods=1)
        j = j+1
  return dados_est

# %%
dados_est = corrigindo_nao_estacionaridade(dados_bac,n_difis,'pmc')
dados_est
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2003-01-01                    NaN               NaN     NaN
# 2003-02-01                   0.00            -29.00    0.04
# 2003-03-01                   0.00             68.00   -0.21
# 2003-04-01                   0.03           -273.00   -0.46
# 2003-05-01                   0.00            -10.00    0.08
# ...                           ...               ...     ...
# 2022-10-01                    NaN             90.00   -0.15
# 2022-11-01                    NaN            238.00    0.04
# 2022-12-01                    NaN               NaN   -0.08
# 2023-01-01                    NaN               NaN   -0.12
# 2023-02-01                    NaN               NaN     NaN
#
#             endividamento_exhabit   cheques        imc  icc_fecomercio  ipca  \
# 2003-01-01                    NaN       NaN 1526624.62             NaN  2.25
# 2003-02-01                   0.00 -50778.00 1526624.62            0.56  1.57
# 2003-03-01                   0.00   6113.00 1459716.38           -1.64  1.23
# 2003-04-01                  -0.01  15976.00 1462875.38            5.77  0.97
# 2003-05-01                   0.00 -35578.00 1463866.62            4.38  0.61
# ...                           ...       ...        ...             ...   ...
# 2022-10-01                    NaN 146999.00 1742839.00            2.77  0.59
# 2022-11-01                    NaN       NaN        NaN            2.56  0.41
# 2022-12-01                    NaN       NaN        NaN            6.05  0.62
# 2023-01-01                    NaN       NaN        NaN            2.54  0.53
# 2023-02-01                    NaN       NaN        NaN             NaN   NaN
#
#             estoque_empregos_com  selic  ...  \
# 2003-01-01                   NaN    NaN  ...
# 2003-02-01              22685.08   0.62  ...
# 2003-03-01              14026.62   0.64  ...
# 2003-04-01              16619.00   0.00  ...
# 2003-05-01              15959.79  -0.01  ...
# ...                          ...    ...  ...
# 2022-10-01              25147.46   0.00  ...
# 2022-11-01              25642.09   0.00  ...
# 2022-12-01              24233.42   0.00  ...
# 2023-01-01                   NaN   0.00  ...
# 2023-02-01                   NaN   0.00  ...
#
#             Familias Endividadas (% do total de famílias)  falencias  \
# 2003-01-01                                            NaN       0.00
# 2003-02-01                                           0.00       0.00
# 2003-03-01                                           0.00       0.00
# 2003-04-01                                           0.00       0.00
# 2003-05-01                                          -0.00       0.00
# ...                                                   ...        ...
# 2022-10-01                                          -0.00      10.00
# 2022-11-01                                          -0.00      24.00
# 2022-12-01                                          -0.01      10.00
# 2023-01-01                                           0.00        NaN
# 2023-02-01                                            NaN        NaN
#
#             nascimento  damanda_credito poupanca  icva    pmc  pib_expec  \
# 2003-01-01         NaN              NaN      NaN   NaN  44.34        NaN
# 2003-02-01        0.00             0.00    -0.15 -0.00  42.70       0.05
# 2003-03-01     -228.12             0.00    -0.20 -0.00  42.79       0.05
# 2003-04-01      -97.96           -14.36    -0.18  0.00  43.70      -0.10
# 2003-05-01     -188.13             0.65    -0.11  0.00  45.61       0.00
# ...                ...              ...      ...   ...    ...        ...
# 2022-10-01    -3872.00            -6.08    -0.13   NaN  97.51       0.23
# 2022-11-01         NaN            -3.47    -0.09   NaN 101.58       0.02
# 2022-12-01         NaN           -10.58     0.05   NaN 113.10      -0.13
# 2023-01-01         NaN              NaN      NaN   NaN    NaN       0.10
# 2023-02-01         NaN              NaN      NaN   NaN    NaN      -0.01
#
#             msad_deflacionado dummy_covid
# 2003-01-01                NaN           0
# 2003-02-01             777.08           0
# 2003-03-01               0.00           0
# 2003-04-01            -777.08           0
# 2003-05-01             623.75           0
# ...                       ...         ...
# 2022-10-01                NaN           0
# 2022-11-01                NaN           0
# 2022-12-01                NaN           0
# 2023-01-01                NaN           0
# 2023-02-01                NaN           0
#
# [242 rows x 24 columns]

# %%
plotar(dados_est)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
report_ndiffs(dados_est)
# Out:
#                                                kpss  adf  pp  Ndifis
# pmc                                               1    1   0       1
# comprometimento_renda                             0    0   0       0
# cons_energia_com                                  0    0   0       0
# msad_deflacionado                                 0    0   0       0
# pib_expec                                         0    0   0       0
# icva                                              0    0   0       0
# poupanca                                          0    0   0       0
# damanda_credito                                   0    0   0       0
# nascimento                                        0    0   0       0
# falencias                                         1    0   0       0
# Familias Endividadas (% do total de famílias)     0    0   0       0
# credito                                           0    0   0       0
# atividade                                         0    0   0       0
# icf                                               0    0   0       0
# juros_cred_livre_pf                               0    0   0       0
# selic                                             0    0   0       0
# estoque_empregos_com                              1    0   0       0
# ipca                                              0    0   0       0
# icc_fecomercio                                    0    0   0       0
# imc                                               1    0   0       0
# cheques                                           0    0   0       0
# endividamento_exhabit                             0    1   0       0
# cambio                                            0    0   0       0
# dummy_covid                                       0    0   0       0

# %% [markdown]
# ##Corrigir atrasos de publicacao

# %%
dados_est = dados_est[2:]

# %%
dados_est
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2003-03-01                   0.00             68.00   -0.21
# 2003-04-01                   0.03           -273.00   -0.46
# 2003-05-01                   0.00            -10.00    0.08
# 2003-06-01                   0.05           -227.00   -0.09
# 2003-07-01                   0.01            -44.00    0.09
# ...                           ...               ...     ...
# 2022-10-01                    NaN             90.00   -0.15
# 2022-11-01                    NaN            238.00    0.04
# 2022-12-01                    NaN               NaN   -0.08
# 2023-01-01                    NaN               NaN   -0.12
# 2023-02-01                    NaN               NaN     NaN
#
#             endividamento_exhabit   cheques        imc  icc_fecomercio  ipca  \
# 2003-03-01                   0.00   6113.00 1459716.38           -1.64  1.23
# 2003-04-01                  -0.01  15976.00 1462875.38            5.77  0.97
# 2003-05-01                   0.00 -35578.00 1463866.62            4.38  0.61
# 2003-06-01                  -0.00  41884.00 1472338.88            4.77 -0.15
# 2003-07-01                   0.02 -19801.00 1474811.25           -5.34  0.20
# ...                           ...       ...        ...             ...   ...
# 2022-10-01                    NaN 146999.00 1742839.00            2.77  0.59
# 2022-11-01                    NaN       NaN        NaN            2.56  0.41
# 2022-12-01                    NaN       NaN        NaN            6.05  0.62
# 2023-01-01                    NaN       NaN        NaN            2.54  0.53
# 2023-02-01                    NaN       NaN        NaN             NaN   NaN
#
#             estoque_empregos_com  selic  ...  \
# 2003-03-01              14026.62   0.64  ...
# 2003-04-01              16619.00   0.00  ...
# 2003-05-01              15959.79  -0.01  ...
# 2003-06-01              16415.29  -0.22  ...
# 2003-07-01              17312.34  -0.73  ...
# ...                          ...    ...  ...
# 2022-10-01              25147.46   0.00  ...
# 2022-11-01              25642.09   0.00  ...
# 2022-12-01              24233.42   0.00  ...
# 2023-01-01                   NaN   0.00  ...
# 2023-02-01                   NaN   0.00  ...
#
#             Familias Endividadas (% do total de famílias)  falencias  \
# 2003-03-01                                           0.00       0.00
# 2003-04-01                                           0.00       0.00
# 2003-05-01                                          -0.00       0.00
# 2003-06-01                                          -0.00       0.00
# 2003-07-01                                           0.00       0.00
# ...                                                   ...        ...
# 2022-10-01                                          -0.00      10.00
# 2022-11-01                                          -0.00      24.00
# 2022-12-01                                          -0.01      10.00
# 2023-01-01                                           0.00        NaN
# 2023-02-01                                            NaN        NaN
#
#             nascimento  damanda_credito poupanca  icva    pmc  pib_expec  \
# 2003-03-01     -228.12             0.00    -0.20 -0.00  42.79       0.05
# 2003-04-01      -97.96           -14.36    -0.18  0.00  43.70      -0.10
# 2003-05-01     -188.13             0.65    -0.11  0.00  45.61       0.00
# 2003-06-01     1119.49            -0.67    -0.09 -0.00  42.97       0.16
# 2003-07-01        0.00             0.19    -0.06  0.00  46.24      -0.06
# ...                ...              ...      ...   ...    ...        ...
# 2022-10-01    -3872.00            -6.08    -0.13   NaN  97.51       0.23
# 2022-11-01         NaN            -3.47    -0.09   NaN 101.58       0.02
# 2022-12-01         NaN           -10.58     0.05   NaN 113.10      -0.13
# 2023-01-01         NaN              NaN      NaN   NaN    NaN       0.10
# 2023-02-01         NaN              NaN      NaN   NaN    NaN      -0.01
#
#             msad_deflacionado dummy_covid
# 2003-03-01               0.00           0
# 2003-04-01            -777.08           0
# 2003-05-01             623.75           0
# 2003-06-01             524.20           0
# 2003-07-01             707.44           0
# ...                       ...         ...
# 2022-10-01                NaN           0
# 2022-11-01                NaN           0
# 2022-12-01                NaN           0
# 2023-01-01                NaN           0
# 2023-02-01                NaN           0
#
# [240 rows x 24 columns]

# %%
##Substituindo os ultimos valores pelos anterires
#dad = dados_est.fillna(method='ffill')

# %%
dados_sem = dados_est.copy()
for k in dados_est.columns[dados_sem.isnull().sum() > 0]:
  model_arima = arima.auto_arima(dados_sem[k].dropna().values, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
  model_arima.fit(dados_sem[k].values)
  a = model_arima.predict(n_periods=int(dados_sem[k].isnull().sum()))
  for i in a:
    dados_sem[k] = dados_sem[k].fillna(i,limit=1)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=11.877, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=33.047, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=10.351, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=13.318, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=10.889, Time=0.07 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=7.912, Time=0.16 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=-15.423, Time=0.14 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=-12.829, Time=0.09 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=-28.393, Time=0.17 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=-26.589, Time=0.18 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=-26.538, Time=0.42 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=-27.988, Time=0.21 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=-30.010, Time=0.35 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-27.251, Time=0.28 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=-18.287, Time=0.42 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=-28.027, Time=1.42 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=5.936, Time=0.84 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=-29.911, Time=0.91 sec
#
# Best model:  ARIMA(3,0,2)(0,0,0)[0] intercept
# Total fit time: 5.928 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=3291.017, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=3320.684, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=3289.884, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=3290.206, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=3290.767, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=3261.928, Time=0.52 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=3255.395, Time=0.48 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=3291.076, Time=0.11 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=1.30 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=1.14 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=3249.407, Time=0.53 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=3256.564, Time=0.44 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=3292.551, Time=0.06 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.78 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=3292.321, Time=0.05 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=3216.974, Time=0.75 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=3294.588, Time=0.23 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.77 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=3292.587, Time=0.07 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=3293.488, Time=0.45 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.97 sec
#
# Best model:  ARIMA(2,0,2)(0,0,0)[0] intercept
# Total fit time: 9.084 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-228.008, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-231.117, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-229.661, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-229.588, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-229.565, Time=0.06 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0]
# Total fit time: 0.383 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-4.407, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=104.916, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=25.970, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-6.235, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=102.930, Time=0.03 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-4.340, Time=0.22 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-2.737, Time=0.32 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-8.001, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-6.242, Time=0.09 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-6.151, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=23.979, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-4.576, Time=0.11 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 1.508 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=6249.019, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=6248.873, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=6247.932, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=6247.540, Time=0.02 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=6248.883, Time=0.03 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=6245.861, Time=0.11 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=6252.862, Time=0.10 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=6247.724, Time=0.15 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=6250.975, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=6250.807, Time=0.07 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=6231.501, Time=0.39 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=inf, Time=0.70 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=6230.173, Time=0.44 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=6252.736, Time=0.25 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=6232.053, Time=1.07 sec
#
# Best model:  ARIMA(3,0,2)(0,0,0)[0]
# Total fit time: 3.571 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=6165.429, Time=0.45 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=6163.242, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=6164.427, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=6164.583, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=6161.269, Time=0.02 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.726 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1474.042, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1472.632, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1472.043, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1472.118, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=1474.040, Time=0.10 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1475.914, Time=0.25 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1473.984, Time=0.14 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 0.822 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=96.881, Time=0.18 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=417.808, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=101.082, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=256.800, Time=0.08 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.79 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=87.344, Time=0.28 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=195.157, Time=0.16 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.95 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=80.823, Time=0.52 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=162.609, Time=0.24 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.51 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=68.067, Time=0.43 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=67.756, Time=0.12 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=71.967, Time=0.10 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=66.810, Time=0.35 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=64.850, Time=0.14 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=85.303, Time=0.11 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=62.909, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=157.705, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=64.847, Time=0.13 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=66.858, Time=0.13 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 5.568 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=5446.331, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5733.603, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=5448.404, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=5575.342, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=5444.021, Time=0.09 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=5448.404, Time=0.03 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=5433.001, Time=0.25 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=5437.241, Time=0.06 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=5431.300, Time=0.28 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=5429.580, Time=0.16 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=5435.619, Time=0.08 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=5431.240, Time=0.30 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=5431.999, Time=0.14 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=5433.266, Time=0.64 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=5430.560, Time=0.14 sec
#
# Best model:  ARIMA(2,0,2)(0,0,0)[0]
# Total fit time: 2.319 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-470.782, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-468.866, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-470.685, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-470.926, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=-469.329, Time=0.10 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=-470.578, Time=0.37 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-472.671, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-471.583, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-472.823, Time=0.22 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-472.404, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-470.852, Time=0.45 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-470.843, Time=0.39 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=-471.350, Time=0.21 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-470.669, Time=0.12 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-471.121, Time=0.58 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 2.913 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1116.776, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1116.207, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1115.815, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1115.450, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1116.301, Time=0.07 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1107.545, Time=0.16 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=1102.133, Time=0.16 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1107.333, Time=0.13 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=1099.274, Time=0.46 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=1107.338, Time=0.13 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=1106.133, Time=0.26 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=1099.423, Time=0.39 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=1100.348, Time=1.09 sec
#
# Best model:  ARIMA(3,0,2)(0,0,0)[0]
# Total fit time: 3.018 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1456.288, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1490.595, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1454.429, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1457.519, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=1456.267, Time=0.07 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1453.822, Time=0.44 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=1457.998, Time=0.41 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=1452.367, Time=0.83 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1458.224, Time=0.25 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=1453.680, Time=1.29 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=1445.337, Time=0.51 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1453.237, Time=0.31 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=1439.422, Time=1.35 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.88 sec
#
# Best model:  ARIMA(3,0,3)(0,0,0)[0]
# Total fit time: 6.725 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-2300.965, Time=0.17 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-2303.340, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-2302.905, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-2302.947, Time=0.06 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-2301.601, Time=0.08 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0]
# Total fit time: 0.431 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=2455.468, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=2843.671, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=2474.266, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=2680.345, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=2447.398, Time=0.09 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=2446.558, Time=0.09 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=2446.071, Time=0.09 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=2444.442, Time=0.20 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=0.48 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=2440.815, Time=0.23 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=2441.944, Time=0.09 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=2432.931, Time=0.36 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=2443.665, Time=0.14 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=2433.228, Time=0.41 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=2429.965, Time=0.59 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=2440.651, Time=0.36 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=2435.124, Time=0.43 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=2424.730, Time=0.69 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.72 sec
#
# Best model:  ARIMA(3,0,3)(0,0,0)[0] intercept
# Total fit time: 5.221 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=4684.790, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4725.677, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4694.828, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4687.283, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=4683.117, Time=0.12 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4690.930, Time=0.02 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=4685.016, Time=0.14 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=4685.063, Time=0.12 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=4683.698, Time=0.10 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4692.919, Time=0.03 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=4686.215, Time=0.24 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=4688.464, Time=0.20 sec
#
# Best model:  ARIMA(2,0,1)(0,0,0)[0]
# Total fit time: 1.097 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1456.288, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1490.595, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1454.429, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1457.519, Time=0.03 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=1456.267, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1453.822, Time=0.20 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=1457.998, Time=0.18 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=1452.367, Time=0.36 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1458.224, Time=0.09 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=1453.680, Time=1.09 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=1445.337, Time=0.57 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1453.237, Time=1.48 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=1439.422, Time=2.30 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=1.66 sec
#
# Best model:  ARIMA(3,0,3)(0,0,0)[0]
# Total fit time: 8.120 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-416.751, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-345.068, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-407.539, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-387.344, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-414.758, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=-414.758, Time=0.14 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=-398.414, Time=0.08 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-414.525, Time=0.07 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=-414.429, Time=0.24 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-414.755, Time=0.12 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 0.997 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-834.657, Time=0.24 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-830.219, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-828.225, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-828.226, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-834.504, Time=0.34 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=-834.412, Time=0.21 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=-828.614, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-827.895, Time=0.03 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=-831.799, Time=0.39 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-833.403, Time=0.45 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 1.878 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1638.948, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1713.188, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1688.468, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1646.667, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1711.450, Time=0.01 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1639.500, Time=0.20 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1630.596, Time=0.30 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1637.270, Time=0.12 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1632.309, Time=0.26 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1632.380, Time=0.42 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1638.158, Time=0.17 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=1634.167, Time=0.49 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1633.440, Time=0.28 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0] intercept
# Total fit time: 2.623 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=4713.780, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4741.709, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4713.463, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4715.478, Time=0.03 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=4709.758, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=4671.443, Time=0.07 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=4672.899, Time=0.09 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=4685.284, Time=0.10 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=4671.026, Time=0.09 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4710.603, Time=0.04 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=4672.620, Time=0.15 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=4678.906, Time=0.36 sec
#
# Best model:  ARIMA(3,0,0)(0,0,0)[0] intercept
# Total fit time: 1.098 seconds

# %%
dados_sem
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2003-03-01                   0.00             68.00   -0.21
# 2003-04-01                   0.03           -273.00   -0.46
# 2003-05-01                   0.00            -10.00    0.08
# 2003-06-01                   0.05           -227.00   -0.09
# 2003-07-01                   0.01            -44.00    0.09
# ...                           ...               ...     ...
# 2022-10-01                   0.04             90.00   -0.15
# 2022-11-01                   0.04            238.00    0.04
# 2022-12-01                   0.04           -232.09   -0.08
# 2023-01-01                   0.04           -307.83   -0.12
# 2023-02-01                   0.04           -299.64    0.00
#
#             endividamento_exhabit   cheques        imc  icc_fecomercio  ipca  \
# 2003-03-01                   0.00   6113.00 1459716.38           -1.64  1.23
# 2003-04-01                  -0.01  15976.00 1462875.38            5.77  0.97
# 2003-05-01                   0.00 -35578.00 1463866.62            4.38  0.61
# 2003-06-01                  -0.00  41884.00 1472338.88            4.77 -0.15
# 2003-07-01                   0.02 -19801.00 1474811.25           -5.34  0.20
# ...                           ...       ...        ...             ...   ...
# 2022-10-01                   0.33 146999.00 1742839.00            2.77  0.59
# 2022-11-01                   0.33 -21035.42 1742839.00            2.56  0.41
# 2022-12-01                   0.33 -40638.37 1742839.00            6.05  0.62
# 2023-01-01                   0.33  14202.82 1742839.00            2.54  0.53
# 2023-02-01                   0.33  36369.27 1742839.00            0.03  0.49
#
#             estoque_empregos_com  selic  ...  \
# 2003-03-01              14026.62   0.64  ...
# 2003-04-01              16619.00   0.00  ...
# 2003-05-01              15959.79  -0.01  ...
# 2003-06-01              16415.29  -0.22  ...
# 2003-07-01              17312.34  -0.73  ...
# ...                          ...    ...  ...
# 2022-10-01              25147.46   0.00  ...
# 2022-11-01              25642.09   0.00  ...
# 2022-12-01              24233.42   0.00  ...
# 2023-01-01              27400.95   0.00  ...
# 2023-02-01              27487.14   0.00  ...
#
#             Familias Endividadas (% do total de famílias)  falencias  \
# 2003-03-01                                           0.00       0.00
# 2003-04-01                                           0.00       0.00
# 2003-05-01                                          -0.00       0.00
# 2003-06-01                                          -0.00       0.00
# 2003-07-01                                           0.00       0.00
# ...                                                   ...        ...
# 2022-10-01                                          -0.00      10.00
# 2022-11-01                                          -0.00      24.00
# 2022-12-01                                          -0.01      10.00
# 2023-01-01                                           0.00      25.52
# 2023-02-01                                           0.00      30.35
#
#             nascimento  damanda_credito  poupanca  icva    pmc  pib_expec  \
# 2003-03-01     -228.12             0.00     -0.20 -0.00  42.79       0.05
# 2003-04-01      -97.96           -14.36     -0.18  0.00  43.70      -0.10
# 2003-05-01     -188.13             0.65     -0.11  0.00  45.61       0.00
# 2003-06-01     1119.49            -0.67     -0.09 -0.00  42.97       0.16
# 2003-07-01        0.00             0.19     -0.06  0.00  46.24      -0.06
# ...                ...              ...       ...   ...    ...        ...
# 2022-10-01    -3872.00            -6.08     -0.13 -0.00  97.51       0.23
# 2022-11-01      263.69            -3.47     -0.09 -0.00 101.58       0.02
# 2022-12-01      161.44           -10.58      0.05 -0.00 113.10      -0.13
# 2023-01-01      102.24             4.37     -0.01 -0.00 103.31       0.10
# 2023-02-01       63.93            -2.44     -0.01 -0.00 102.30      -0.01
#
#             msad_deflacionado  dummy_covid
# 2003-03-01               0.00            0
# 2003-04-01            -777.08            0
# 2003-05-01             623.75            0
# 2003-06-01             524.20            0
# 2003-07-01             707.44            0
# ...                       ...          ...
# 2022-10-01             707.17            0
# 2022-11-01             633.68            0
# 2022-12-01             599.16            0
# 2023-01-01             609.50            0
# 2023-02-01             643.14            0
#
# [240 rows x 24 columns]

# %%
for i in dados_bac.columns:
  plt.plot(dados_sem[i], label= 'Dados sem Nan')
  plt.plot(dados_est[i], label = 'Dados com Nan')
  plt.title(i)
  plt.legend()
  plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
dados_sem.to_csv('dados_pmc.csv')

# %% [markdown]
# ##Dividindo os dados em treino e teste

# %%
dados_sem
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2003-03-01                   0.00             68.00   -0.21
# 2003-04-01                   0.03           -273.00   -0.46
# 2003-05-01                   0.00            -10.00    0.08
# 2003-06-01                   0.05           -227.00   -0.09
# 2003-07-01                   0.01            -44.00    0.09
# ...                           ...               ...     ...
# 2022-10-01                   0.04             90.00   -0.15
# 2022-11-01                   0.04            238.00    0.04
# 2022-12-01                   0.04           -232.09   -0.08
# 2023-01-01                   0.04           -307.83   -0.12
# 2023-02-01                   0.04           -299.64    0.00
#
#             endividamento_exhabit   cheques        imc  icc_fecomercio  ipca  \
# 2003-03-01                   0.00   6113.00 1459716.38           -1.64  1.23
# 2003-04-01                  -0.01  15976.00 1462875.38            5.77  0.97
# 2003-05-01                   0.00 -35578.00 1463866.62            4.38  0.61
# 2003-06-01                  -0.00  41884.00 1472338.88            4.77 -0.15
# 2003-07-01                   0.02 -19801.00 1474811.25           -5.34  0.20
# ...                           ...       ...        ...             ...   ...
# 2022-10-01                   0.33 146999.00 1742839.00            2.77  0.59
# 2022-11-01                   0.33 -21035.42 1742839.00            2.56  0.41
# 2022-12-01                   0.33 -40638.37 1742839.00            6.05  0.62
# 2023-01-01                   0.33  14202.82 1742839.00            2.54  0.53
# 2023-02-01                   0.33  36369.27 1742839.00            0.03  0.49
#
#             estoque_empregos_com  selic  ...  \
# 2003-03-01              14026.62   0.64  ...
# 2003-04-01              16619.00   0.00  ...
# 2003-05-01              15959.79  -0.01  ...
# 2003-06-01              16415.29  -0.22  ...
# 2003-07-01              17312.34  -0.73  ...
# ...                          ...    ...  ...
# 2022-10-01              25147.46   0.00  ...
# 2022-11-01              25642.09   0.00  ...
# 2022-12-01              24233.42   0.00  ...
# 2023-01-01              27400.95   0.00  ...
# 2023-02-01              27487.14   0.00  ...
#
#             Familias Endividadas (% do total de famílias)  falencias  \
# 2003-03-01                                           0.00       0.00
# 2003-04-01                                           0.00       0.00
# 2003-05-01                                          -0.00       0.00
# 2003-06-01                                          -0.00       0.00
# 2003-07-01                                           0.00       0.00
# ...                                                   ...        ...
# 2022-10-01                                          -0.00      10.00
# 2022-11-01                                          -0.00      24.00
# 2022-12-01                                          -0.01      10.00
# 2023-01-01                                           0.00      25.52
# 2023-02-01                                           0.00      30.35
#
#             nascimento  damanda_credito  poupanca  icva    pmc  pib_expec  \
# 2003-03-01     -228.12             0.00     -0.20 -0.00  42.79       0.05
# 2003-04-01      -97.96           -14.36     -0.18  0.00  43.70      -0.10
# 2003-05-01     -188.13             0.65     -0.11  0.00  45.61       0.00
# 2003-06-01     1119.49            -0.67     -0.09 -0.00  42.97       0.16
# 2003-07-01        0.00             0.19     -0.06  0.00  46.24      -0.06
# ...                ...              ...       ...   ...    ...        ...
# 2022-10-01    -3872.00            -6.08     -0.13 -0.00  97.51       0.23
# 2022-11-01      263.69            -3.47     -0.09 -0.00 101.58       0.02
# 2022-12-01      161.44           -10.58      0.05 -0.00 113.10      -0.13
# 2023-01-01      102.24             4.37     -0.01 -0.00 103.31       0.10
# 2023-02-01       63.93            -2.44     -0.01 -0.00 102.30      -0.01
#
#             msad_deflacionado  dummy_covid
# 2003-03-01               0.00            0
# 2003-04-01            -777.08            0
# 2003-05-01             623.75            0
# 2003-06-01             524.20            0
# 2003-07-01             707.44            0
# ...                       ...          ...
# 2022-10-01             707.17            0
# 2022-11-01             633.68            0
# 2022-12-01             599.16            0
# 2023-01-01             609.50            0
# 2023-02-01             643.14            0
#
# [240 rows x 24 columns]

# %%
treino = dados_sem[dados_sem.index < pd.to_datetime('2021-01-01')]

# %%
treino.head()
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2003-03-01                   0.00             68.00   -0.21
# 2003-04-01                   0.03           -273.00   -0.46
# 2003-05-01                   0.00            -10.00    0.08
# 2003-06-01                   0.05           -227.00   -0.09
# 2003-07-01                   0.01            -44.00    0.09
#
#             endividamento_exhabit   cheques        imc  icc_fecomercio  ipca  \
# 2003-03-01                   0.00   6113.00 1459716.38           -1.64  1.23
# 2003-04-01                  -0.01  15976.00 1462875.38            5.77  0.97
# 2003-05-01                   0.00 -35578.00 1463866.62            4.38  0.61
# 2003-06-01                  -0.00  41884.00 1472338.88            4.77 -0.15
# 2003-07-01                   0.02 -19801.00 1474811.25           -5.34  0.20
#
#             estoque_empregos_com  selic  ...  \
# 2003-03-01              14026.62   0.64  ...
# 2003-04-01              16619.00   0.00  ...
# 2003-05-01              15959.79  -0.01  ...
# 2003-06-01              16415.29  -0.22  ...
# 2003-07-01              17312.34  -0.73  ...
#
#             Familias Endividadas (% do total de famílias)  falencias  \
# 2003-03-01                                           0.00       0.00
# 2003-04-01                                           0.00       0.00
# 2003-05-01                                          -0.00       0.00
# 2003-06-01                                          -0.00       0.00
# 2003-07-01                                           0.00       0.00
#
#             nascimento  damanda_credito  poupanca  icva   pmc  pib_expec  \
# 2003-03-01     -228.12             0.00     -0.20 -0.00 42.79       0.05
# 2003-04-01      -97.96           -14.36     -0.18  0.00 43.70      -0.10
# 2003-05-01     -188.13             0.65     -0.11  0.00 45.61       0.00
# 2003-06-01     1119.49            -0.67     -0.09 -0.00 42.97       0.16
# 2003-07-01        0.00             0.19     -0.06  0.00 46.24      -0.06
#
#             msad_deflacionado  dummy_covid
# 2003-03-01               0.00            0
# 2003-04-01            -777.08            0
# 2003-05-01             623.75            0
# 2003-06-01             524.20            0
# 2003-07-01             707.44            0
#
# [5 rows x 24 columns]

# %%
y_treino = treino['pmc'].values
x_treino = treino.loc[:,treino.columns != 'pmc'].values

# %%
teste = dados_sem[dados_sem.index >= pd.to_datetime('2021-01-01')]

# %%
teste.head()
# Out:
#             comprometimento_renda  cons_energia_com  cambio  \
# 2021-01-01                  -0.18             15.00    0.28
# 2021-02-01                  -0.54            -34.00    0.05
# 2021-03-01                   0.09            484.00    0.17
# 2021-04-01                  -0.45           -743.00   -0.29
# 2021-05-01                   0.69           -443.00   -0.17
#
#             endividamento_exhabit    cheques        imc  icc_fecomercio  ipca  \
# 2021-01-01                   0.36  447060.00 1986719.00            4.38  0.25
# 2021-02-01                   0.28   98302.00 2128209.00            0.14  0.86
# 2021-03-01                   0.27 -960529.00 1168521.00           -3.33  0.93
# 2021-04-01                   0.20 -177830.00 1204380.00           -7.95  0.31
# 2021-05-01                   0.72   90987.00 1203387.00            0.95  0.83
#
#             estoque_empregos_com  selic  ...  \
# 2021-01-01              91412.46   0.00  ...
# 2021-02-01             106973.94   0.00  ...
# 2021-03-01              18102.65   0.33  ...
# 2021-04-01               -953.74   0.42  ...
# 2021-05-01              54487.52   0.64  ...
#
#             Familias Endividadas (% do total de famílias)  falencias  \
# 2021-01-01                                          -0.00       9.00
# 2021-02-01                                           0.00      16.00
# 2021-03-01                                          -0.00      15.00
# 2021-04-01                                          -0.00       7.00
# 2021-05-01                                           0.00      23.00
#
#             nascimento  damanda_credito  poupanca  icva   pmc  pib_expec  \
# 2021-01-01     4275.57            -1.09     -0.34  0.01 91.65       0.33
# 2021-02-01    -2574.89           -11.13     -0.19 -0.03 85.85       0.10
# 2021-03-01     4489.72            -1.84     -0.24  0.02 91.67      -0.08
# 2021-04-01     -142.52             4.26     -0.19  0.29 91.99      -0.08
# 2021-05-01     -287.60            15.59     -0.20  0.02 99.19       0.02
#
#             msad_deflacionado  dummy_covid
# 2021-01-01           -3756.13            0
# 2021-02-01             131.34            0
# 2021-03-01          -19060.18            0
# 2021-04-01            1614.56            0
# 2021-05-01           -2370.24            0
#
# [5 rows x 24 columns]

# %%
y_teste = teste['pmc'].values
x_teste= teste.loc[:,teste.columns != 'pmc'].values

# %% [markdown]
# #Aplicando Grid Search

# %% [markdown]
# ##Treinando o RandomForestRegressor

# %%
from scipy.stats import randint as sp_randint

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, make_scorer
# definindo os hiperparâmetros
param_grid = {
  "n_estimators": [10, 20,50,60,100],
  "max_depth": [1,2,30,70,100],
  "min_samples_split": [2, 6,8,11],
  "min_samples_leaf": [1,4,9,11],
  "max_features": [1, 3,10,15,23],
  'criterion':['squared_error','absolute_error','friedman_mse']
}

# definição do RMSE como métrica de avaliação



# instanciando o modelo de random forest
rf = RandomForestRegressor()

# instanciando o randomized search
#random_search = RandomizedSearchCV(estimator=rf, param_distributions=param_grid, scoring= ['neg_root_mean_squared_error','neg_mean_absolute_percentage_error','neg_mean_absolute_error'], refit=False, cv=5, verbose=3)

search = GridSearchCV(estimator=rf, param_grid=param_grid, scoring= 'neg_root_mean_squared_error', cv=5, verbose=3)


# fit no modelo
search.fit(x_treino, y_treino)

# print dos melhores hiperparâmetros
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=10;, score=-27.230 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=10;, score=-16.046 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=10;, score=-11.576 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=10;, score=-10.496 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=10;, score=-11.855 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=20;, score=-25.267 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=20;, score=-16.483 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=20;, score=-9.717 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=20;, score=-8.665 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=20;, score=-11.546 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=50;, score=-25.865 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=50;, score=-15.051 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=50;, score=-10.153 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=50;, score=-9.352 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=50;, score=-11.816 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=60;, score=-26.153 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=60;, score=-16.478 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=60;, score=-10.177 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=60;, score=-9.003 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=60;, score=-11.664 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=100;, score=-26.033 total time=   0.2s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=100;, score=-16.173 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=100;, score=-10.769 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=100;, score=-8.989 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=100;, score=-11.449 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=10;, score=-26.034 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=10;, score=-15.706 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=10;, score=-10.818 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=10;, score=-9.416 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=10;, score=-11.312 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=20;, score=-25.438 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=20;, score=-16.135 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=20;, score=-12.517 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=20;, score=-9.748 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=20;, score=-12.260 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=50;, score=-25.454 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=50;, score=-15.903 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=50;, score=-10.497 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=50;, score=-9.632 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=50;, score=-12.043 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=60;, score=-25.153 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=60;, score=-15.498 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=60;, score=-10.721 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=60;, score=-9.078 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=60;, score=-11.714 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=100;, score=-25.852 total time=   0.2s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=100;, score=-16.235 total time=   0.2s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=100;, score=-11.265 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=100;, score=-8.857 total time=   0.3s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=6, n_estimators=100;, score=-11.986 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=10;, score=-26.303 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=10;, score=-16.380 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=10;, score=-8.875 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=10;, score=-8.759 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=10;, score=-11.518 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=20;, score=-25.669 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=20;, score=-16.613 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=20;, score=-9.922 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=20;, score=-9.906 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=20;, score=-12.193 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=50;, score=-26.683 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=50;, score=-15.947 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=50;, score=-9.681 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=50;, score=-9.331 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=50;, score=-11.722 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=60;, score=-25.509 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=60;, score=-15.927 total time=   0.2s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=60;, score=-10.177 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=60;, score=-9.330 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=60;, score=-10.991 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=100;, score=-26.114 total time=   0.2s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=100;, score=-15.575 total time=   0.2s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=100;, score=-10.070 total time=   0.3s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=100;, score=-8.873 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=8, n_estimators=100;, score=-11.833 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=10;, score=-25.184 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=10;, score=-16.681 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=10;, score=-9.326 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=10;, score=-8.733 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=10;, score=-11.327 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=20;, score=-27.278 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=20;, score=-16.222 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=20;, score=-10.152 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=20;, score=-9.758 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=20;, score=-11.405 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=50;, score=-25.717 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=50;, score=-15.468 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=50;, score=-10.887 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=50;, score=-8.953 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=50;, score=-11.660 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=60;, score=-25.738 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=60;, score=-15.279 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=60;, score=-11.068 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=60;, score=-9.146 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=60;, score=-11.721 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=100;, score=-26.477 total time=   0.2s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=100;, score=-15.754 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=100;, score=-10.757 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=100;, score=-8.997 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=9, min_samples_split=11, n_estimators=100;, score=-11.845 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=10;, score=-28.376 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=10;, score=-20.066 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=10;, score=-12.390 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=10;, score=-11.721 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=10;, score=-12.560 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=20;, score=-26.014 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=20;, score=-17.954 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=20;, score=-11.826 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=20;, score=-9.085 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=20;, score=-11.835 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=50;, score=-26.342 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=50;, score=-16.090 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=50;, score=-10.435 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=50;, score=-9.426 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=50;, score=-11.894 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=60;, score=-27.123 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=60;, score=-15.680 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=60;, score=-11.550 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=60;, score=-9.640 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=60;, score=-12.526 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=100;, score=-26.586 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=100;, score=-15.333 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=100;, score=-11.049 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=100;, score=-10.111 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=100;, score=-11.871 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=10;, score=-26.909 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=10;, score=-13.226 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=10;, score=-12.215 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=10;, score=-9.072 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=10;, score=-11.978 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=20;, score=-27.602 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=20;, score=-15.817 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=20;, score=-10.822 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=20;, score=-9.111 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=20;, score=-11.264 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=50;, score=-26.463 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=50;, score=-15.704 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=50;, score=-10.462 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=50;, score=-9.923 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=50;, score=-11.805 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=60;, score=-25.912 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=60;, score=-15.632 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=60;, score=-11.384 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=60;, score=-9.335 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=60;, score=-11.884 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=100;, score=-26.695 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=100;, score=-16.506 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=100;, score=-10.230 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=100;, score=-9.035 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=6, n_estimators=100;, score=-11.933 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=10;, score=-27.780 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=10;, score=-13.322 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=10;, score=-9.221 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=10;, score=-9.355 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=10;, score=-11.096 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=20;, score=-25.959 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=20;, score=-15.076 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=20;, score=-11.766 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=20;, score=-8.984 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=20;, score=-12.028 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=50;, score=-26.623 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=50;, score=-15.772 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=50;, score=-10.791 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=50;, score=-10.385 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=50;, score=-11.991 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=60;, score=-26.716 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=60;, score=-15.404 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=60;, score=-11.158 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=60;, score=-9.638 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=60;, score=-12.881 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=100;, score=-26.193 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=100;, score=-14.688 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=100;, score=-10.284 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=100;, score=-9.617 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=8, n_estimators=100;, score=-12.339 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=10;, score=-26.434 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=10;, score=-14.817 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=10;, score=-11.264 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=10;, score=-9.062 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=10;, score=-13.081 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=20;, score=-27.364 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=20;, score=-14.661 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=20;, score=-11.422 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=20;, score=-8.758 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=20;, score=-11.249 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=50;, score=-26.729 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=50;, score=-16.028 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=50;, score=-11.193 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=50;, score=-9.392 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=50;, score=-12.315 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=60;, score=-26.079 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=60;, score=-15.042 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=60;, score=-9.982 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=60;, score=-9.868 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=60;, score=-11.178 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=100;, score=-26.776 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=100;, score=-15.469 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=100;, score=-10.880 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=100;, score=-9.694 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=10, min_samples_leaf=11, min_samples_split=11, n_estimators=100;, score=-11.995 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=-23.435 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=-14.993 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=-9.462 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=-9.192 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=-10.029 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=-23.846 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=-16.759 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=-9.537 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=-9.390 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=-9.846 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-24.539 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-15.746 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-10.039 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-8.538 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-10.528 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=60;, score=-23.756 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=60;, score=-16.130 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=60;, score=-9.782 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=60;, score=-8.383 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=60;, score=-10.395 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-24.245 total time=   0.3s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-15.524 total time=   0.3s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-10.013 total time=   0.3s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-8.336 total time=   0.3s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-10.394 total time=   0.3s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=10;, score=-23.845 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=10;, score=-16.016 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=10;, score=-9.336 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=10;, score=-7.629 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=10;, score=-10.964 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=20;, score=-24.696 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=20;, score=-16.632 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=20;, score=-9.553 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=20;, score=-6.887 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=20;, score=-11.150 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=50;, score=-24.138 total time=   0.2s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=50;, score=-15.765 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=50;, score=-9.855 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=50;, score=-8.421 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=50;, score=-9.812 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=60;, score=-24.835 total time=   0.2s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=60;, score=-15.530 total time=   0.2s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=60;, score=-9.487 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=60;, score=-7.820 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=60;, score=-9.914 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=-24.363 total time=   0.3s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=-15.837 total time=   0.3s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=-9.303 total time=   0.3s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=-8.725 total time=   0.3s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=-10.229 total time=   0.3s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=10;, score=-23.989 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=10;, score=-14.877 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=10;, score=-10.561 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=10;, score=-8.862 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=10;, score=-11.505 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=20;, score=-22.818 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=20;, score=-15.942 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=20;, score=-9.472 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=20;, score=-8.272 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=20;, score=-10.484 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=50;, score=-23.842 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=50;, score=-16.833 total time=   0.2s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=50;, score=-9.570 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=50;, score=-8.317 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=50;, score=-9.974 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=60;, score=-24.907 total time=   0.2s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=60;, score=-16.155 total time=   0.2s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=60;, score=-9.520 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=60;, score=-8.320 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=60;, score=-9.213 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=100;, score=-23.949 total time=   0.2s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=100;, score=-16.717 total time=   0.2s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=100;, score=-9.546 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=100;, score=-8.332 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=8, n_estimators=100;, score=-9.603 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=10;, score=-23.744 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=10;, score=-17.269 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=10;, score=-10.476 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=10;, score=-8.484 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=10;, score=-9.273 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=20;, score=-24.671 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=20;, score=-16.926 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=20;, score=-10.353 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=20;, score=-9.204 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=20;, score=-10.318 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=50;, score=-24.324 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=50;, score=-15.301 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=50;, score=-9.542 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=50;, score=-9.242 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=50;, score=-9.626 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=60;, score=-24.464 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=60;, score=-16.720 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=60;, score=-10.617 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=60;, score=-8.757 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=60;, score=-8.846 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=100;, score=-24.496 total time=   0.2s
# [CV 2/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=100;, score=-15.747 total time=   0.2s
# [CV 3/5] END criterion=friedman_mse, max_depth=30, max_features=15, min_samples_leaf=1, min_samples_split=11, n_estimators=100;, score=-10.116 total time=   0.2s
# ...
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=20;, score=-25.958 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=20;, score=-18.460 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=20;, score=-11.572 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=20;, score=-11.384 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=20;, score=-12.514 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=50;, score=-25.813 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=50;, score=-18.158 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=50;, score=-11.582 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=50;, score=-10.351 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=50;, score=-12.761 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=60;, score=-26.524 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=60;, score=-18.500 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=60;, score=-10.500 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=60;, score=-10.803 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=60;, score=-12.923 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=100;, score=-26.136 total time=   0.2s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=100;, score=-18.298 total time=   0.2s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=100;, score=-10.875 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=100;, score=-10.500 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=2, n_estimators=100;, score=-13.146 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=10;, score=-27.169 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=10;, score=-18.522 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=10;, score=-11.316 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=10;, score=-10.573 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=10;, score=-12.367 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=20;, score=-27.173 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=20;, score=-18.323 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=20;, score=-11.399 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=20;, score=-9.609 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=20;, score=-12.795 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=50;, score=-25.987 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=50;, score=-18.184 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=50;, score=-11.031 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=50;, score=-10.663 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=50;, score=-12.988 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=60;, score=-25.858 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=60;, score=-18.603 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=60;, score=-10.790 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=60;, score=-10.056 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=60;, score=-12.960 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=100;, score=-26.414 total time=   0.2s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=100;, score=-18.295 total time=   0.2s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=100;, score=-10.492 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=100;, score=-10.457 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=6, n_estimators=100;, score=-12.821 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=10;, score=-26.711 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=10;, score=-19.231 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=10;, score=-10.200 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=10;, score=-11.926 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=10;, score=-13.762 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=20;, score=-25.524 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=20;, score=-17.765 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=20;, score=-10.587 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=20;, score=-10.760 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=20;, score=-12.447 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=50;, score=-26.226 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=50;, score=-18.442 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=50;, score=-10.533 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=50;, score=-10.385 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=50;, score=-13.074 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=60;, score=-26.382 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=60;, score=-18.830 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=60;, score=-10.678 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=60;, score=-11.027 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=60;, score=-12.336 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=100;, score=-25.979 total time=   0.2s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=100;, score=-18.279 total time=   0.2s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=100;, score=-10.014 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=100;, score=-10.369 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=8, n_estimators=100;, score=-12.673 total time=   0.2s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=10;, score=-24.664 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=10;, score=-17.717 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=10;, score=-11.154 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=10;, score=-10.314 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=10;, score=-13.233 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=20;, score=-27.076 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=20;, score=-18.391 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=20;, score=-10.747 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=20;, score=-11.352 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=20;, score=-12.881 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=50;, score=-26.279 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=50;, score=-18.789 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=50;, score=-10.702 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=50;, score=-10.282 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=50;, score=-13.134 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=60;, score=-26.227 total time=   0.1s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=60;, score=-18.151 total time=   0.1s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=60;, score=-10.467 total time=   0.1s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=60;, score=-10.308 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=60;, score=-12.884 total time=   0.1s
# [CV 1/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=100;, score=-25.834 total time=   0.2s
# [CV 2/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=100;, score=-18.568 total time=   0.2s
# [CV 3/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=100;, score=-10.513 total time=   0.2s
# [CV 4/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=100;, score=-10.176 total time=   0.2s
# [CV 5/5] END criterion=friedman_mse, max_depth=100, max_features=23, min_samples_leaf=11, min_samples_split=11, n_estimators=100;, score=-12.747 total time=   0.2s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_depth': [1, 2, 30, 70, 100],
#                          'max_features': [1, 3, 10, 15, 23],
#                          'min_samples_leaf': [1, 4, 9, 11],
#                          'min_samples_split': [2, 6, 8, 11],
#                          'n_estimators': [10, 20, 50, 60, 100]},
#              scoring='neg_root_mean_squared_error', verbose=3)

# %%
search.best_estimator_
# Out:
# RandomForestRegressor(max_depth=100, max_features=15, min_samples_leaf=4,
#                       min_samples_split=8, n_estimators=20)

# %% [markdown]
# ##Treinando o Reggressao lasso

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

models = [LinearRegression(), Ridge(), Lasso()]
param_grid = [
    {'fit_intercept': [True, False]},
    {'alpha': np.logspace(-3, 3, 1000)},
    {'alpha': np.logspace(-3, 3, 1020)}]
for model, param_grid_model in zip(models, param_grid):
    grid_search = GridSearchCV(model, param_grid_model, scoring='neg_mean_squared_error', cv=5, return_train_score=True)
    grid_search.fit(x_treino, y_treino)
    print(f"Model: {type(model).__name__}")
    print(f"Best parameters: {grid_search.best_params_}")
    print(f"Best cross-validation score: {grid_search.best_score_}")
    print("")
# Out:
# Model: LinearRegression
# Best parameters: {'fit_intercept': False}
# Best cross-validation score: -650.0559384084943
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.00785e-16): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.01966e-16): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.03163e-16): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.04377e-16): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.05608e-16): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.06856e-16): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.08121e-16): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.09405e-16): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.10706e-16): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Model: Ridge
# Best parameters: {'alpha': 0.001}
# Best cross-validation score: -820.3824493484742
#
# Model: Lasso
# Best parameters: {'alpha': 84.79322206477522}
# Best cross-validation score: -239.99960817201364

# %% [markdown]
# ## Treinando gradiente Bosting

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# Carregue os dados de treinamento e teste

# Lista com os modelos de regressão a serem testados
models = [LinearRegression(), Ridge(), Lasso(), DecisionTreeRegressor(), RandomForestRegressor(), GradientBoostingRegressor()]

# Dicionário com os parâmetros a serem testados para cada modelo
param_grid = [
    {'fit_intercept': [True, False]},
    {'alpha': np.logspace(-3, 3, 7)},
    {'alpha': np.logspace(-3, 3, 7)},
    {'max_depth': [None, 1, 2, 3, 4, 5]},
    {'n_estimators': [10, 50, 100, 200, 500], 'max_depth': [None, 1, 2, 3, 4, 5]},
    {'n_estimators': [10, 50, 100, 200, 500], 'learning_rate': [0.1, 0.05, 0.01]}
]

# Loop através de cada modelo
for model, param_grid_model in zip(models, param_grid):
    grid_search = GridSearchCV(model, param_grid_model, scoring='neg_mean_squared_error', cv=5, return_train_score=True)
    grid_search.fit(x_treino, y_treino)
    print(f"Model: {type(model).__name__}")
    print(f"Best parameters: {grid_search.best_params_}")
    print(f"Best cross-validation score: {grid_search.best_score_}")
    print("")

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
# instanciar o modelo de Gradient Boosting
model = GradientBoostingRegressor()

# definir os hiperparâmetros a serem testados
param_grid = {
    "loss":["ls", "lad", "huber", "quantile"],
    "learning_rate":[0.1, 0.05, 0.01],
    "n_estimators":[100, 250, 500],
    "max_depth":[3, 5, 7, 9],
    "min_samples_split":[2, 4, 8],
    "min_samples_leaf":[1, 2, 4]
}

# instanciar o GridSearchCV
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error',verbose=3)

# fit no modelo
grid_search.fit(x_treino, y_treino)

# print dos melhores hiperparâmetros
print("Melhores hiperparâmetros: ", grid_search.best_params_)

# prever com os melhores hiperparâmetros
y_pred = grid_search.predict(x_teste)

# %%
grid_search.best_estimator_
# Out:
# GradientBoostingRegressor(loss='lad', max_depth=5, min_samples_leaf=2,
#                           min_samples_split=4, n_estimators=500)

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.1,
#  'loss': 'lad',
#  'max_depth': 5,
#  'min_samples_leaf': 2,
#  'min_samples_split': 4,
#  'n_estimators': 500}

# %%
grid_search.best_score_
# Out:
# -187.41472930081662

# %% [markdown]
# #Treinando os modelos com os melhores paramentros

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_regression(y_true, y_pred, algorithm):
    metrics = {}
    metrics['MAE'] = mean_absolute_error(y_true, y_pred)
    metrics['MSE'] = mean_squared_error(y_true, y_pred)
    metrics['RMSE'] = np.sqrt(metrics['MSE'])
    metrics['R²'] = r2_score(y_true, y_pred)
    metrics_df = pd.DataFrame(metrics, index=[algorithm])
    return metrics_df

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
lasso = Lasso(random_state=0,alpha=84.79)
lasso.fit(x_treino, y_treino)
# Out:
# Lasso(alpha=84.79, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(max_depth=100, max_features=15, min_samples_leaf=4, min_samples_split=8, n_estimators=20)
rfr.fit(x_treino, y_treino)
# Out:
# RandomForestRegressor(max_depth=100, max_features=15, min_samples_leaf=4,
#                       min_samples_split=8, n_estimators=20)

# %%
from sklearn.ensemble import GradientBoostingRegressor
grad_bost = GradientBoostingRegressor(random_state=0, learning_rate= 0.1,loss='absolute_error',max_depth=5, min_samples_leaf= 2,min_samples_split=4,n_estimators=500)
grad_bost.fit(x_treino, y_treino)
# Out:
# GradientBoostingRegressor(loss='absolute_error', max_depth=5,
#                           min_samples_leaf=2, min_samples_split=4,
#                           n_estimators=500, random_state=0)

# %%
import tensorflow as tf

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=25,activation='relu',input_shape=(x_treino.shape[1],),activity_regularizer='l1'))
model.add(tf.keras.layers.Dropout(0.20))
model.add(tf.keras.layers.Dense(units=25,activation='relu',activity_regularizer='l1'))
model.add(tf.keras.layers.Dropout(0.20))
model.add(tf.keras.layers.Dense(units=25,activation='relu',activity_regularizer='l1'))
model.add(tf.keras.layers.Dropout(0.15))
model.add(tf.keras.layers.Dense(units=1,activation='linear'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.fit(x_treino, y_treino, epochs=2000,batch_size=100)
# Out:
# Epoch 1/2000
# 3/3 [==============================] - 4s 10ms/step - loss: 19639558144.0000 - mean_absolute_error: 112610.8594
# Epoch 2/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 16070081536.0000 - mean_absolute_error: 97880.3516
# Epoch 3/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 10820536320.0000 - mean_absolute_error: 83962.8125
# Epoch 4/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 8068858880.0000 - mean_absolute_error: 72246.0859
# Epoch 5/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 9284762624.0000 - mean_absolute_error: 73153.9453
# Epoch 6/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 7826786304.0000 - mean_absolute_error: 69383.5547
# Epoch 7/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 5396617728.0000 - mean_absolute_error: 58693.7070
# Epoch 8/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 4840909824.0000 - mean_absolute_error: 53596.8906
# Epoch 9/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 5851209216.0000 - mean_absolute_error: 57234.4805
# Epoch 10/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 5188408320.0000 - mean_absolute_error: 53896.9609
# Epoch 11/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 3683596544.0000 - mean_absolute_error: 46763.3164
# Epoch 12/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 4020307968.0000 - mean_absolute_error: 49508.4375
# Epoch 13/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 3763487488.0000 - mean_absolute_error: 47819.4102
# Epoch 14/2000
# 3/3 [==============================] - 0s 11ms/step - loss: 3275164160.0000 - mean_absolute_error: 43362.4844
# Epoch 15/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 2351335168.0000 - mean_absolute_error: 38324.2227
# Epoch 16/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 2433007360.0000 - mean_absolute_error: 39973.3594
# Epoch 17/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 2371411200.0000 - mean_absolute_error: 38421.5898
# Epoch 18/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 2544266240.0000 - mean_absolute_error: 38994.2539
# Epoch 19/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 2042091648.0000 - mean_absolute_error: 34888.9609
# Epoch 20/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 2441091328.0000 - mean_absolute_error: 38813.8594
# Epoch 21/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 2119636608.0000 - mean_absolute_error: 36384.7422
# Epoch 22/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 2048433152.0000 - mean_absolute_error: 35153.0742
# Epoch 23/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 2080022144.0000 - mean_absolute_error: 34187.0859
# Epoch 24/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 1765132416.0000 - mean_absolute_error: 30903.7852
# Epoch 25/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 1507563904.0000 - mean_absolute_error: 30238.5801
# Epoch 26/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 1726532480.0000 - mean_absolute_error: 32568.5215
# Epoch 27/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 1670988416.0000 - mean_absolute_error: 31086.4199
# Epoch 28/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 1369737600.0000 - mean_absolute_error: 28698.4785
# Epoch 29/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 1379749888.0000 - mean_absolute_error: 29292.4414
# Epoch 30/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 1542222336.0000 - mean_absolute_error: 29918.9043
# Epoch 31/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 1219305984.0000 - mean_absolute_error: 27189.5273
# Epoch 32/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 1323251200.0000 - mean_absolute_error: 28605.6387
# Epoch 33/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 1024868736.0000 - mean_absolute_error: 24983.6426
# Epoch 34/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 968407104.0000 - mean_absolute_error: 23959.8359
# Epoch 35/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 980928896.0000 - mean_absolute_error: 24238.3418
# Epoch 36/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 919927296.0000 - mean_absolute_error: 24706.9316
# Epoch 37/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 887914624.0000 - mean_absolute_error: 23381.9160
# Epoch 38/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 807149632.0000 - mean_absolute_error: 22253.0469
# Epoch 39/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 747896704.0000 - mean_absolute_error: 21945.4570
# Epoch 40/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 698299456.0000 - mean_absolute_error: 20676.1035
# Epoch 41/2000
# 3/3 [==============================] - 0s 11ms/step - loss: 882855488.0000 - mean_absolute_error: 22795.8340
# Epoch 42/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 796697408.0000 - mean_absolute_error: 21204.0625
# Epoch 43/2000
# 3/3 [==============================] - 0s 13ms/step - loss: 677428864.0000 - mean_absolute_error: 19893.1504
# Epoch 44/2000
# 3/3 [==============================] - 0s 11ms/step - loss: 742979520.0000 - mean_absolute_error: 20850.8809
# Epoch 45/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 806580352.0000 - mean_absolute_error: 21931.8105
# Epoch 46/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 720119680.0000 - mean_absolute_error: 20999.6582
# Epoch 47/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 843030784.0000 - mean_absolute_error: 21693.7168
# Epoch 48/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 642389312.0000 - mean_absolute_error: 19527.0371
# Epoch 49/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 599469824.0000 - mean_absolute_error: 18894.9746
# Epoch 50/2000
# 3/3 [==============================] - 0s 12ms/step - loss: 614804608.0000 - mean_absolute_error: 19956.3770
# Epoch 51/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 670370752.0000 - mean_absolute_error: 18931.3262
# Epoch 52/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 601464704.0000 - mean_absolute_error: 18263.4375
# Epoch 53/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 458853376.0000 - mean_absolute_error: 16918.0918
# Epoch 54/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 613198784.0000 - mean_absolute_error: 18840.1406
# Epoch 55/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 596649920.0000 - mean_absolute_error: 18396.2871
# Epoch 56/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 459982496.0000 - mean_absolute_error: 16545.3965
# Epoch 57/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 418978784.0000 - mean_absolute_error: 15552.2490
# Epoch 58/2000
# 3/3 [==============================] - 0s 12ms/step - loss: 530402528.0000 - mean_absolute_error: 16933.4980
# Epoch 59/2000
# 3/3 [==============================] - 0s 11ms/step - loss: 400146240.0000 - mean_absolute_error: 15079.5586
# Epoch 60/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 411795072.0000 - mean_absolute_error: 15057.6660
# Epoch 61/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 380531072.0000 - mean_absolute_error: 14879.4404
# Epoch 62/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 447408672.0000 - mean_absolute_error: 15407.6445
# Epoch 63/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 424544768.0000 - mean_absolute_error: 16502.8359
# Epoch 64/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 382541696.0000 - mean_absolute_error: 14491.1504
# Epoch 65/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 352755648.0000 - mean_absolute_error: 14643.9346
# Epoch 66/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 401124928.0000 - mean_absolute_error: 15300.7568
# Epoch 67/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 420143616.0000 - mean_absolute_error: 15154.2188
# Epoch 68/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 325345088.0000 - mean_absolute_error: 13600.9326
# Epoch 69/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 432299968.0000 - mean_absolute_error: 15574.7090
# Epoch 70/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 314070720.0000 - mean_absolute_error: 13043.5479
# Epoch 71/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 360327520.0000 - mean_absolute_error: 13678.5889
# Epoch 72/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 274560448.0000 - mean_absolute_error: 12885.3711
# Epoch 73/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 290521088.0000 - mean_absolute_error: 13034.1133
# Epoch 74/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 310155744.0000 - mean_absolute_error: 13359.7959
# Epoch 75/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 242650624.0000 - mean_absolute_error: 11742.5342
# Epoch 76/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 295562240.0000 - mean_absolute_error: 13035.1846
# Epoch 77/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 265383712.0000 - mean_absolute_error: 12381.4648
# Epoch 78/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 322471968.0000 - mean_absolute_error: 12476.5381
# Epoch 79/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 256218736.0000 - mean_absolute_error: 12247.1191
# Epoch 80/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 192798112.0000 - mean_absolute_error: 10380.3223
# Epoch 81/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 242034240.0000 - mean_absolute_error: 11704.2617
# Epoch 82/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 346089056.0000 - mean_absolute_error: 13865.6289
# Epoch 83/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 262077296.0000 - mean_absolute_error: 12092.4404
# Epoch 84/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 268765408.0000 - mean_absolute_error: 12080.7656
# Epoch 85/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 281606592.0000 - mean_absolute_error: 13126.5020
# Epoch 86/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 203532960.0000 - mean_absolute_error: 11520.0479
# Epoch 87/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 282584224.0000 - mean_absolute_error: 12615.0322
# Epoch 88/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 260478160.0000 - mean_absolute_error: 12060.2803
# Epoch 89/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 243164032.0000 - mean_absolute_error: 11627.1621
# Epoch 90/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 185300800.0000 - mean_absolute_error: 10612.6631
# Epoch 91/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 168572640.0000 - mean_absolute_error: 10135.6367
# Epoch 92/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 197904032.0000 - mean_absolute_error: 10940.1016
# Epoch 93/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 260778880.0000 - mean_absolute_error: 11999.4102
# Epoch 94/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 156805472.0000 - mean_absolute_error: 9672.1172
# Epoch 95/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 206832592.0000 - mean_absolute_error: 10750.9717
# Epoch 96/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 229611904.0000 - mean_absolute_error: 11194.1572
# Epoch 97/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 186156704.0000 - mean_absolute_error: 10234.7881
# Epoch 98/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 199452320.0000 - mean_absolute_error: 10623.5498
# Epoch 99/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 188491952.0000 - mean_absolute_error: 10202.7549
# Epoch 100/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 195787696.0000 - mean_absolute_error: 10508.8691
# Epoch 101/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 240791024.0000 - mean_absolute_error: 11639.9570
# Epoch 102/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 246064208.0000 - mean_absolute_error: 11058.9287
# Epoch 103/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 167051328.0000 - mean_absolute_error: 9288.9785
# Epoch 104/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 161254224.0000 - mean_absolute_error: 9384.2686
# Epoch 105/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 134325280.0000 - mean_absolute_error: 8920.4844
# Epoch 106/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 158859696.0000 - mean_absolute_error: 9572.7451
# Epoch 107/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 179960592.0000 - mean_absolute_error: 9663.2852
# Epoch 108/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 155641248.0000 - mean_absolute_error: 8991.3828
# Epoch 109/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 229113552.0000 - mean_absolute_error: 9469.5342
# Epoch 110/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 118203600.0000 - mean_absolute_error: 8140.1528
# Epoch 111/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 143424064.0000 - mean_absolute_error: 8598.0537
# Epoch 112/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 141167760.0000 - mean_absolute_error: 8742.5791
# Epoch 113/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 140572576.0000 - mean_absolute_error: 8899.5986
# Epoch 114/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 148328512.0000 - mean_absolute_error: 8546.8906
# Epoch 115/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 132794352.0000 - mean_absolute_error: 8085.6006
# Epoch 116/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 122701496.0000 - mean_absolute_error: 8380.5889
# Epoch 117/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 152289200.0000 - mean_absolute_error: 8507.5283
# Epoch 118/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 143188816.0000 - mean_absolute_error: 8654.2979
# Epoch 119/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 152087248.0000 - mean_absolute_error: 8879.5215
# Epoch 120/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 129709200.0000 - mean_absolute_error: 7782.0645
# Epoch 121/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 112000424.0000 - mean_absolute_error: 7801.9185
# Epoch 122/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 92532448.0000 - mean_absolute_error: 6993.9263
# Epoch 123/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 90828184.0000 - mean_absolute_error: 7379.2983
# Epoch 124/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 111978968.0000 - mean_absolute_error: 7391.5229
# Epoch 125/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 104349256.0000 - mean_absolute_error: 7301.9395
# Epoch 126/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 84079512.0000 - mean_absolute_error: 6938.0703
# Epoch 127/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 128273400.0000 - mean_absolute_error: 8104.8179
# Epoch 128/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 117668608.0000 - mean_absolute_error: 7492.7627
# Epoch 129/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 87179528.0000 - mean_absolute_error: 7245.9844
# Epoch 130/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 123553368.0000 - mean_absolute_error: 8001.3413
# Epoch 131/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 87028248.0000 - mean_absolute_error: 6495.2988
# Epoch 132/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 122368440.0000 - mean_absolute_error: 7175.1279
# Epoch 133/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 73438408.0000 - mean_absolute_error: 6279.4912
# Epoch 134/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 90586656.0000 - mean_absolute_error: 7097.4346
# Epoch 135/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 111909168.0000 - mean_absolute_error: 7399.9653
# Epoch 136/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 100502352.0000 - mean_absolute_error: 7083.9795
# Epoch 137/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 82078784.0000 - mean_absolute_error: 6091.2251
# Epoch 138/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 102340560.0000 - mean_absolute_error: 6910.4136
# Epoch 139/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 75815296.0000 - mean_absolute_error: 5797.9126
# Epoch 140/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 65246312.0000 - mean_absolute_error: 5991.0537
# Epoch 141/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 62692236.0000 - mean_absolute_error: 5438.3252
# Epoch 142/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 78815072.0000 - mean_absolute_error: 6121.3940
# Epoch 143/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 64248400.0000 - mean_absolute_error: 5670.8657
# Epoch 144/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 60578460.0000 - mean_absolute_error: 5406.5840
# Epoch 145/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 66685152.0000 - mean_absolute_error: 5938.5244
# Epoch 146/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 48427096.0000 - mean_absolute_error: 5047.1338
# Epoch 147/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 58181744.0000 - mean_absolute_error: 5295.4614
# Epoch 148/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 51357744.0000 - mean_absolute_error: 5140.7422
# Epoch 149/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 62333140.0000 - mean_absolute_error: 5679.5615
# Epoch 150/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 66677856.0000 - mean_absolute_error: 5787.0352
# Epoch 151/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 59588324.0000 - mean_absolute_error: 5374.0977
# Epoch 152/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 37710524.0000 - mean_absolute_error: 4280.7720
# Epoch 153/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 51142476.0000 - mean_absolute_error: 5126.3149
# Epoch 154/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 48918008.0000 - mean_absolute_error: 4980.6558
# Epoch 155/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 52618420.0000 - mean_absolute_error: 5016.5605
# Epoch 156/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 57464952.0000 - mean_absolute_error: 5019.1030
# Epoch 157/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 67421600.0000 - mean_absolute_error: 5119.6001
# Epoch 158/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 52240020.0000 - mean_absolute_error: 4916.1143
# Epoch 159/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 62603356.0000 - mean_absolute_error: 5313.3999
# Epoch 160/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 46144884.0000 - mean_absolute_error: 4799.8906
# Epoch 161/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 51095696.0000 - mean_absolute_error: 5021.0576
# Epoch 162/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 47216392.0000 - mean_absolute_error: 4831.1357
# Epoch 163/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 44591012.0000 - mean_absolute_error: 4556.4204
# Epoch 164/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 57880496.0000 - mean_absolute_error: 4832.5703
# Epoch 165/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 41011180.0000 - mean_absolute_error: 3979.4966
# Epoch 166/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 42889092.0000 - mean_absolute_error: 4387.6646
# Epoch 167/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 41613572.0000 - mean_absolute_error: 4341.9839
# Epoch 168/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 53575704.0000 - mean_absolute_error: 4722.6680
# Epoch 169/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 48433656.0000 - mean_absolute_error: 4533.4980
# Epoch 170/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 51252768.0000 - mean_absolute_error: 4708.5205
# Epoch 171/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 46390848.0000 - mean_absolute_error: 4545.5967
# Epoch 172/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 54818524.0000 - mean_absolute_error: 4841.5918
# Epoch 173/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 46596332.0000 - mean_absolute_error: 4515.1040
# Epoch 174/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 50169604.0000 - mean_absolute_error: 4503.2334
# Epoch 175/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 42722304.0000 - mean_absolute_error: 4566.8042
# Epoch 176/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 34788516.0000 - mean_absolute_error: 3797.7524
# Epoch 177/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 31422608.0000 - mean_absolute_error: 3959.1760
# Epoch 178/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 34873236.0000 - mean_absolute_error: 3868.3123
# Epoch 179/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 30661916.0000 - mean_absolute_error: 3643.7903
# Epoch 180/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 27670048.0000 - mean_absolute_error: 3626.0134
# Epoch 181/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 24994978.0000 - mean_absolute_error: 3309.0874
# Epoch 182/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 74024432.0000 - mean_absolute_error: 4377.7832
# Epoch 183/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 36719372.0000 - mean_absolute_error: 3931.3977
# Epoch 184/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 50763748.0000 - mean_absolute_error: 4185.7568
# Epoch 185/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 28037752.0000 - mean_absolute_error: 3332.2646
# Epoch 186/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 27346582.0000 - mean_absolute_error: 3316.4875
# Epoch 187/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 22729098.0000 - mean_absolute_error: 3327.2134
# Epoch 188/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 30268148.0000 - mean_absolute_error: 3576.9165
# Epoch 189/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 37999604.0000 - mean_absolute_error: 3604.8604
# Epoch 190/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 55453184.0000 - mean_absolute_error: 4194.0298
# Epoch 191/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 31654532.0000 - mean_absolute_error: 3582.8149
# Epoch 192/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 32973640.0000 - mean_absolute_error: 3594.5635
# Epoch 193/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 21513546.0000 - mean_absolute_error: 3010.3955
# Epoch 194/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 19910856.0000 - mean_absolute_error: 2941.4619
# Epoch 195/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 34961988.0000 - mean_absolute_error: 3515.4424
# Epoch 196/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 32965618.0000 - mean_absolute_error: 3295.9290
# Epoch 197/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 18738436.0000 - mean_absolute_error: 2767.5312
# Epoch 198/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 29472666.0000 - mean_absolute_error: 3288.9761
# Epoch 199/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 35347880.0000 - mean_absolute_error: 3330.4944
# Epoch 200/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 30531484.0000 - mean_absolute_error: 3388.5095
# Epoch 201/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 35507980.0000 - mean_absolute_error: 3319.7698
# Epoch 202/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 41517124.0000 - mean_absolute_error: 3538.7617
# Epoch 203/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 17174800.0000 - mean_absolute_error: 2721.1968
# Epoch 204/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 22665940.0000 - mean_absolute_error: 2950.5544
# Epoch 205/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 24239168.0000 - mean_absolute_error: 2965.7856
# Epoch 206/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 20093188.0000 - mean_absolute_error: 2691.3660
# Epoch 207/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 27619244.0000 - mean_absolute_error: 2961.8889
# Epoch 208/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 20282964.0000 - mean_absolute_error: 2657.0398
# Epoch 209/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 24127082.0000 - mean_absolute_error: 2889.2456
# Epoch 210/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 21688966.0000 - mean_absolute_error: 2866.7798
# Epoch 211/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 37089412.0000 - mean_absolute_error: 3307.1216
# Epoch 212/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 15500111.0000 - mean_absolute_error: 2458.1279
# Epoch 213/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 40503152.0000 - mean_absolute_error: 3351.9465
# Epoch 214/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 24965764.0000 - mean_absolute_error: 2779.1965
# Epoch 215/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 14569941.0000 - mean_absolute_error: 2386.0020
# Epoch 216/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 21328400.0000 - mean_absolute_error: 2538.3938
# Epoch 217/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 28679086.0000 - mean_absolute_error: 2935.7327
# Epoch 218/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 17934488.0000 - mean_absolute_error: 2164.3159
# Epoch 219/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 13328735.0000 - mean_absolute_error: 2358.5193
# Epoch 220/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 19325680.0000 - mean_absolute_error: 2600.8015
# Epoch 221/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 20698554.0000 - mean_absolute_error: 2614.3572
# Epoch 222/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 31049044.0000 - mean_absolute_error: 2784.5674
# Epoch 223/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 17881092.0000 - mean_absolute_error: 2407.2229
# Epoch 224/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 23746136.0000 - mean_absolute_error: 2729.3169
# Epoch 225/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 26830498.0000 - mean_absolute_error: 2658.0015
# Epoch 226/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 22691484.0000 - mean_absolute_error: 2614.4602
# Epoch 227/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 12746256.0000 - mean_absolute_error: 2017.9562
# Epoch 228/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 21766118.0000 - mean_absolute_error: 2395.8066
# Epoch 229/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 15628445.0000 - mean_absolute_error: 2142.4553
# Epoch 230/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 23547982.0000 - mean_absolute_error: 2632.5903
# Epoch 231/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 21509184.0000 - mean_absolute_error: 2497.0703
# Epoch 232/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 18495102.0000 - mean_absolute_error: 2464.0457
# Epoch 233/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 37877900.0000 - mean_absolute_error: 2919.3130
# Epoch 234/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 13647004.0000 - mean_absolute_error: 1828.3350
# Epoch 235/2000
# 3/3 [==============================] - 0s 11ms/step - loss: 26394148.0000 - mean_absolute_error: 2560.1951
# Epoch 236/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 23440880.0000 - mean_absolute_error: 2458.4556
# Epoch 237/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 18395530.0000 - mean_absolute_error: 2346.8320
# Epoch 238/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 26674680.0000 - mean_absolute_error: 2589.3184
# Epoch 239/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 21790452.0000 - mean_absolute_error: 2367.4570
# Epoch 240/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 13933573.0000 - mean_absolute_error: 2001.6372
# Epoch 241/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 24815928.0000 - mean_absolute_error: 2459.2856
# Epoch 242/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 10825680.0000 - mean_absolute_error: 1843.8773
# Epoch 243/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 16012411.0000 - mean_absolute_error: 2181.9839
# Epoch 244/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 11941810.0000 - mean_absolute_error: 1864.6013
# Epoch 245/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 13252488.0000 - mean_absolute_error: 1939.0132
# Epoch 246/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 14973722.0000 - mean_absolute_error: 2141.8848
# Epoch 247/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 20448686.0000 - mean_absolute_error: 2100.2991
# Epoch 248/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 11001093.0000 - mean_absolute_error: 1965.2423
# Epoch 249/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 21970692.0000 - mean_absolute_error: 2282.8643
# Epoch 250/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 9018482.0000 - mean_absolute_error: 1488.3817
# Epoch 251/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 18307918.0000 - mean_absolute_error: 2110.5117
# Epoch 252/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 28034900.0000 - mean_absolute_error: 2691.9409
# Epoch 253/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 11854175.0000 - mean_absolute_error: 1665.1451
# Epoch 254/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 15176432.0000 - mean_absolute_error: 2083.6938
# Epoch 255/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 9610531.0000 - mean_absolute_error: 1841.9373
# Epoch 256/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 19044608.0000 - mean_absolute_error: 2169.1067
# Epoch 257/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 13374763.0000 - mean_absolute_error: 1835.5511
# Epoch 258/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 12444018.0000 - mean_absolute_error: 1841.0594
# Epoch 259/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 8710212.0000 - mean_absolute_error: 1671.4745
# Epoch 260/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 14963844.0000 - mean_absolute_error: 2019.5170
# Epoch 261/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 23404544.0000 - mean_absolute_error: 2339.6780
# Epoch 262/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 18872236.0000 - mean_absolute_error: 2190.0940
# Epoch 263/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 19075756.0000 - mean_absolute_error: 2101.8748
# Epoch 264/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 18879400.0000 - mean_absolute_error: 2066.7419
# Epoch 265/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 12099828.0000 - mean_absolute_error: 1639.1707
# Epoch 266/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 9111581.0000 - mean_absolute_error: 1685.9935
# Epoch 267/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 12011117.0000 - mean_absolute_error: 1925.5918
# Epoch 268/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 58437068.0000 - mean_absolute_error: 2633.8435
# Epoch 269/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 13899454.0000 - mean_absolute_error: 1811.5430
# Epoch 270/2000
# 3/3 [==============================] - 0s 11ms/step - loss: 13144234.0000 - mean_absolute_error: 1638.5833
# Epoch 271/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 8963744.0000 - mean_absolute_error: 1550.7031
# Epoch 272/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 12407761.0000 - mean_absolute_error: 1638.5966
# Epoch 273/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 12788664.0000 - mean_absolute_error: 1644.3365
# Epoch 274/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 16462771.0000 - mean_absolute_error: 1912.8090
# Epoch 275/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 9803744.0000 - mean_absolute_error: 1671.9723
# Epoch 276/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 30288606.0000 - mean_absolute_error: 1877.8417
# Epoch 277/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 17104160.0000 - mean_absolute_error: 1695.6680
# Epoch 278/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 18989308.0000 - mean_absolute_error: 1949.7137
# Epoch 279/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 9442047.0000 - mean_absolute_error: 1387.5751
# Epoch 280/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 18754130.0000 - mean_absolute_error: 1876.8280
# Epoch 281/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 11318684.0000 - mean_absolute_error: 1343.1431
# Epoch 282/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 5736636.5000 - mean_absolute_error: 1287.9930
# Epoch 283/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 7213379.0000 - mean_absolute_error: 1185.6005
# Epoch 284/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 5997565.5000 - mean_absolute_error: 1283.6338
# Epoch 285/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 11724372.0000 - mean_absolute_error: 1476.0155
# Epoch 286/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 8769292.0000 - mean_absolute_error: 1386.9856
# Epoch 287/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 21116766.0000 - mean_absolute_error: 1847.3146
# Epoch 288/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 9610230.0000 - mean_absolute_error: 1465.7240
# Epoch 289/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 13481110.0000 - mean_absolute_error: 1700.9977
# Epoch 290/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 11740813.0000 - mean_absolute_error: 1710.4762
# Epoch 291/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 24248054.0000 - mean_absolute_error: 1760.0577
# Epoch 292/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 18596634.0000 - mean_absolute_error: 1811.9596
# Epoch 293/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 9098547.0000 - mean_absolute_error: 1497.7156
# Epoch 294/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 17052188.0000 - mean_absolute_error: 1756.4280
# Epoch 295/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 16206214.0000 - mean_absolute_error: 1547.9121
# Epoch 296/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 6674287.5000 - mean_absolute_error: 1242.0320
# Epoch 297/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 30380772.0000 - mean_absolute_error: 2286.5413
# Epoch 298/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 19679270.0000 - mean_absolute_error: 1791.4271
# Epoch 299/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 7811133.0000 - mean_absolute_error: 1314.4025
# Epoch 300/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 16123128.0000 - mean_absolute_error: 1626.1919
# Epoch 301/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 10921161.0000 - mean_absolute_error: 1715.1848
# Epoch 302/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 13156146.0000 - mean_absolute_error: 1524.7644
# Epoch 303/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 7788158.0000 - mean_absolute_error: 1290.2850
# Epoch 304/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 7257083.0000 - mean_absolute_error: 1026.2292
# Epoch 305/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 9706861.0000 - mean_absolute_error: 1311.6195
# Epoch 306/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 12650391.0000 - mean_absolute_error: 1526.4760
# Epoch 307/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 9156214.0000 - mean_absolute_error: 1252.4084
# Epoch 308/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 28768294.0000 - mean_absolute_error: 1725.4623
# Epoch 309/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 5090718.5000 - mean_absolute_error: 1073.9049
# Epoch 310/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 9877904.0000 - mean_absolute_error: 1327.8982
# Epoch 311/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 13775423.0000 - mean_absolute_error: 1429.6427
# Epoch 312/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 9287449.0000 - mean_absolute_error: 1307.4709
# Epoch 313/2000
# 3/3 [==============================] - 0s 11ms/step - loss: 12233037.0000 - mean_absolute_error: 1375.4685
# Epoch 314/2000
# 3/3 [==============================] - 0s 14ms/step - loss: 6261312.0000 - mean_absolute_error: 1192.7490
# Epoch 315/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 13688529.0000 - mean_absolute_error: 1588.1520
# Epoch 316/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 9475339.0000 - mean_absolute_error: 1421.9586
# Epoch 317/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 11271047.0000 - mean_absolute_error: 1533.9354
# Epoch 318/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 12928211.0000 - mean_absolute_error: 1688.5288
# Epoch 319/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 8093760.5000 - mean_absolute_error: 1182.2394
# Epoch 320/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 19179432.0000 - mean_absolute_error: 1702.2395
# Epoch 321/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 7507022.5000 - mean_absolute_error: 1146.5286
# Epoch 322/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 7018824.0000 - mean_absolute_error: 1129.8851
# Epoch 323/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 16701535.0000 - mean_absolute_error: 1582.6918
# Epoch 324/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 13490765.0000 - mean_absolute_error: 1493.6456
# Epoch 325/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 17971072.0000 - mean_absolute_error: 1571.4097
# Epoch 326/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 8533466.0000 - mean_absolute_error: 1217.7638
# Epoch 327/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 17078478.0000 - mean_absolute_error: 1647.4220
# Epoch 328/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 14688706.0000 - mean_absolute_error: 1522.8313
# Epoch 329/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 12954419.0000 - mean_absolute_error: 1452.5747
# Epoch 330/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 9544330.0000 - mean_absolute_error: 1216.6162
# Epoch 331/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 10303530.0000 - mean_absolute_error: 1221.4403
# Epoch 332/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 17765662.0000 - mean_absolute_error: 1302.4618
# Epoch 333/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 5864616.5000 - mean_absolute_error: 1125.6163
# Epoch 334/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 10812698.0000 - mean_absolute_error: 1175.1335
# Epoch 335/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 8092172.0000 - mean_absolute_error: 1145.9911
# Epoch 336/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 3217100.2500 - mean_absolute_error: 900.0521
# Epoch 337/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 15358950.0000 - mean_absolute_error: 1285.5267
# Epoch 338/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 8481261.0000 - mean_absolute_error: 1265.0959
# Epoch 339/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 8093833.0000 - mean_absolute_error: 1036.7104
# Epoch 340/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 6513207.0000 - mean_absolute_error: 1016.9698
# Epoch 341/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 9546118.0000 - mean_absolute_error: 1402.9198
# Epoch 342/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 9522448.0000 - mean_absolute_error: 1239.3416
# Epoch 343/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 7121438.5000 - mean_absolute_error: 1116.1219
# Epoch 344/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 10212912.0000 - mean_absolute_error: 1521.9724
# Epoch 345/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 9545743.0000 - mean_absolute_error: 1170.7324
# Epoch 346/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 37957236.0000 - mean_absolute_error: 1964.4098
# Epoch 347/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 12209282.0000 - mean_absolute_error: 1273.0240
# Epoch 348/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 10932643.0000 - mean_absolute_error: 1088.7704
# Epoch 349/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 9340355.0000 - mean_absolute_error: 1190.6211
# Epoch 350/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 12173617.0000 - mean_absolute_error: 1192.9629
# Epoch 351/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 12741240.0000 - mean_absolute_error: 1492.5825
# Epoch 352/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 9210122.0000 - mean_absolute_error: 1281.8765
# Epoch 353/2000
# 3/3 [==============================] - 0s 11ms/step - loss: 12904185.0000 - mean_absolute_error: 1349.5426
# Epoch 354/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 5092084.5000 - mean_absolute_error: 991.9566
# Epoch 355/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 9360867.0000 - mean_absolute_error: 1148.0453
# Epoch 356/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 10499811.0000 - mean_absolute_error: 1112.1453
# Epoch 357/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 10604672.0000 - mean_absolute_error: 1406.3339
# Epoch 358/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 9431219.0000 - mean_absolute_error: 1144.4391
# Epoch 359/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 5136904.5000 - mean_absolute_error: 796.1267
# Epoch 360/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 10296040.0000 - mean_absolute_error: 1306.8804
# Epoch 361/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 9004526.0000 - mean_absolute_error: 1096.6119
# Epoch 362/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 6549259.0000 - mean_absolute_error: 950.6946
# Epoch 363/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 11488445.0000 - mean_absolute_error: 1169.1169
# Epoch 364/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 8202375.0000 - mean_absolute_error: 1016.7092
# Epoch 365/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 8063205.5000 - mean_absolute_error: 930.1425
# Epoch 366/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 9068988.0000 - mean_absolute_error: 1132.6234
# Epoch 367/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 8198568.5000 - mean_absolute_error: 1215.5983
# Epoch 368/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 10358022.0000 - mean_absolute_error: 1083.5050
# Epoch 369/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 17169454.0000 - mean_absolute_error: 1288.0992
# Epoch 370/2000
# 3/3 [==============================] - 0s 14ms/step - loss: 4041065.0000 - mean_absolute_error: 773.0294
# Epoch 371/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 17100406.0000 - mean_absolute_error: 1410.6942
# Epoch 372/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 8997192.0000 - mean_absolute_error: 980.0955
# Epoch 373/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 12727935.0000 - mean_absolute_error: 1437.0060
# Epoch 374/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 8761139.0000 - mean_absolute_error: 969.0960
# Epoch 375/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 20911466.0000 - mean_absolute_error: 1467.3921
# Epoch 376/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 14840863.0000 - mean_absolute_error: 1342.7952
# Epoch 377/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 6239555.0000 - mean_absolute_error: 1012.2958
# Epoch 378/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 6812761.0000 - mean_absolute_error: 1100.2030
# Epoch 379/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 9209362.0000 - mean_absolute_error: 1160.0596
# Epoch 380/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 21073452.0000 - mean_absolute_error: 1637.3059
# Epoch 381/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 4656009.5000 - mean_absolute_error: 926.9888
# Epoch 382/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 6459110.5000 - mean_absolute_error: 904.7706
# Epoch 383/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 10066833.0000 - mean_absolute_error: 1113.6493
# Epoch 384/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 8756439.0000 - mean_absolute_error: 1189.6348
# Epoch 385/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 11721046.0000 - mean_absolute_error: 1086.6742
# Epoch 386/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 8032234.5000 - mean_absolute_error: 1142.6085
# Epoch 387/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 7862512.0000 - mean_absolute_error: 969.2922
# Epoch 388/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 7814754.5000 - mean_absolute_error: 1193.1654
# Epoch 389/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 6227102.5000 - mean_absolute_error: 865.2941
# Epoch 390/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 6915410.5000 - mean_absolute_error: 1029.1823
# Epoch 391/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 8057690.5000 - mean_absolute_error: 897.1530
# Epoch 392/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 4880828.5000 - mean_absolute_error: 901.6493
# Epoch 393/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 6851990.0000 - mean_absolute_error: 974.2170
# Epoch 394/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 8173940.5000 - mean_absolute_error: 1157.3767
# Epoch 395/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 5916519.0000 - mean_absolute_error: 1088.3760
# Epoch 396/2000
# ...
# Epoch 1866/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 106895.9219 - mean_absolute_error: 68.8984
# Epoch 1867/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 47204.3164 - mean_absolute_error: 43.2843
# Epoch 1868/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 72327.7812 - mean_absolute_error: 48.3519
# Epoch 1869/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 93170.6641 - mean_absolute_error: 64.3066
# Epoch 1870/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 124532.5391 - mean_absolute_error: 66.0840
# Epoch 1871/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 255001.9375 - mean_absolute_error: 94.5713
# Epoch 1872/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 103623.7734 - mean_absolute_error: 80.0879
# Epoch 1873/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 755451.1875 - mean_absolute_error: 121.2440
# Epoch 1874/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 292461.6562 - mean_absolute_error: 77.5840
# Epoch 1875/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 278889.3125 - mean_absolute_error: 94.4471
# Epoch 1876/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 98361.8438 - mean_absolute_error: 61.3413
# Epoch 1877/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 334501.8438 - mean_absolute_error: 117.5158
# Epoch 1878/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 262712.5000 - mean_absolute_error: 115.0456
# Epoch 1879/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 380708.1250 - mean_absolute_error: 94.3327
# Epoch 1880/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 470928.0312 - mean_absolute_error: 158.5445
# Epoch 1881/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 130118.8984 - mean_absolute_error: 85.5122
# Epoch 1882/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 174228.7969 - mean_absolute_error: 106.7298
# Epoch 1883/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 97060.4297 - mean_absolute_error: 71.6046
# Epoch 1884/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 98493.8047 - mean_absolute_error: 71.5436
# Epoch 1885/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 91011.2891 - mean_absolute_error: 92.8804
# Epoch 1886/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 73850.6953 - mean_absolute_error: 70.8574
# Epoch 1887/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 60743.8555 - mean_absolute_error: 54.4022
# Epoch 1888/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 236515.9688 - mean_absolute_error: 95.6685
# Epoch 1889/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 207139.1719 - mean_absolute_error: 87.1008
# Epoch 1890/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 85127.6016 - mean_absolute_error: 66.9390
# Epoch 1891/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 70754.3203 - mean_absolute_error: 55.5303
# Epoch 1892/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 244135.1719 - mean_absolute_error: 87.2484
# Epoch 1893/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 307225.7188 - mean_absolute_error: 100.4648
# Epoch 1894/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 142802.2188 - mean_absolute_error: 78.8361
# Epoch 1895/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 97985.1094 - mean_absolute_error: 61.3551
# Epoch 1896/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 111936.9141 - mean_absolute_error: 76.5102
# Epoch 1897/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 68547.8047 - mean_absolute_error: 57.8662
# Epoch 1898/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 192216.5156 - mean_absolute_error: 76.3024
# Epoch 1899/2000
# 3/3 [==============================] - 0s 11ms/step - loss: 48211.6172 - mean_absolute_error: 39.9148
# Epoch 1900/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 96027.1016 - mean_absolute_error: 65.2058
# Epoch 1901/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 85173.4219 - mean_absolute_error: 64.5579
# Epoch 1902/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 309773.2500 - mean_absolute_error: 105.6888
# Epoch 1903/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 72291.5078 - mean_absolute_error: 52.7285
# Epoch 1904/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 728252.8125 - mean_absolute_error: 132.6107
# Epoch 1905/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 48108.0312 - mean_absolute_error: 49.6247
# Epoch 1906/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 114984.3750 - mean_absolute_error: 91.7014
# Epoch 1907/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 138578.5625 - mean_absolute_error: 95.3627
# Epoch 1908/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 62786.8008 - mean_absolute_error: 74.0786
# Epoch 1909/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 467954.8125 - mean_absolute_error: 120.1347
# Epoch 1910/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 861974.5625 - mean_absolute_error: 171.2822
# Epoch 1911/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 101680.2578 - mean_absolute_error: 71.9178
# Epoch 1912/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 231936.5000 - mean_absolute_error: 112.6113
# Epoch 1913/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 95141.0625 - mean_absolute_error: 74.7307
# Epoch 1914/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 154262.6875 - mean_absolute_error: 82.5170
# Epoch 1915/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 296112.4062 - mean_absolute_error: 108.0751
# Epoch 1916/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 75309.1250 - mean_absolute_error: 52.5193
# Epoch 1917/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 117353.4609 - mean_absolute_error: 71.4669
# Epoch 1918/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 121431.3438 - mean_absolute_error: 89.1483
# Epoch 1919/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 135643.5781 - mean_absolute_error: 74.8469
# Epoch 1920/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 94057.4688 - mean_absolute_error: 56.8574
# Epoch 1921/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 62524.8320 - mean_absolute_error: 53.4689
# Epoch 1922/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 136375.0312 - mean_absolute_error: 85.3054
# Epoch 1923/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 291392.8125 - mean_absolute_error: 111.3250
# Epoch 1924/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 263267.9062 - mean_absolute_error: 101.1783
# Epoch 1925/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 145595.7344 - mean_absolute_error: 86.4316
# Epoch 1926/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 197099.5938 - mean_absolute_error: 98.8661
# Epoch 1927/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 122830.8984 - mean_absolute_error: 84.8462
# Epoch 1928/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 403327.7500 - mean_absolute_error: 122.4858
# Epoch 1929/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 164242.3438 - mean_absolute_error: 61.0414
# Epoch 1930/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 114138.2422 - mean_absolute_error: 74.8778
# Epoch 1931/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 170552.6875 - mean_absolute_error: 87.2762
# Epoch 1932/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 142198.4531 - mean_absolute_error: 82.9659
# Epoch 1933/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 89126.0391 - mean_absolute_error: 54.8540
# Epoch 1934/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 62239.7344 - mean_absolute_error: 58.3359
# Epoch 1935/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 6833483.5000 - mean_absolute_error: 251.8475
# Epoch 1936/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 124082.4766 - mean_absolute_error: 78.9051
# Epoch 1937/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 75047.2734 - mean_absolute_error: 61.8158
# Epoch 1938/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 114242.0312 - mean_absolute_error: 64.7762
# Epoch 1939/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 146106.2188 - mean_absolute_error: 84.2255
# Epoch 1940/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 171809.2344 - mean_absolute_error: 87.0814
# Epoch 1941/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 75801.1797 - mean_absolute_error: 54.8064
# Epoch 1942/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 44927.5273 - mean_absolute_error: 35.1080
# Epoch 1943/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 184799.2656 - mean_absolute_error: 93.4264
# Epoch 1944/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 132192.4062 - mean_absolute_error: 92.5017
# Epoch 1945/2000
# 3/3 [==============================] - 0s 11ms/step - loss: 80199.0859 - mean_absolute_error: 70.3274
# Epoch 1946/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 265721.4688 - mean_absolute_error: 100.0191
# Epoch 1947/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 86839.3906 - mean_absolute_error: 60.6944
# Epoch 1948/2000
# 3/3 [==============================] - 0s 12ms/step - loss: 259579.5938 - mean_absolute_error: 113.7767
# Epoch 1949/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 688601.1250 - mean_absolute_error: 153.0516
# Epoch 1950/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 133082.9688 - mean_absolute_error: 66.2200
# Epoch 1951/2000
# 3/3 [==============================] - 0s 12ms/step - loss: 360686.1250 - mean_absolute_error: 128.9483
# Epoch 1952/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 75030.2812 - mean_absolute_error: 63.3530
# Epoch 1953/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 459245.1562 - mean_absolute_error: 130.0266
# Epoch 1954/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 73427.0391 - mean_absolute_error: 64.2055
# Epoch 1955/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 45545.5508 - mean_absolute_error: 39.9053
# Epoch 1956/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 79526.2266 - mean_absolute_error: 64.5587
# Epoch 1957/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 151512.2188 - mean_absolute_error: 83.1030
# Epoch 1958/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 229428.8281 - mean_absolute_error: 83.3743
# Epoch 1959/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 184199.5469 - mean_absolute_error: 91.8909
# Epoch 1960/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 64093.8477 - mean_absolute_error: 57.9731
# Epoch 1961/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 52322.3984 - mean_absolute_error: 43.2455
# Epoch 1962/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 46074.4844 - mean_absolute_error: 37.7902
# Epoch 1963/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 115299.7422 - mean_absolute_error: 69.7214
# Epoch 1964/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 89549.1094 - mean_absolute_error: 66.4185
# Epoch 1965/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 452588.5938 - mean_absolute_error: 88.9879
# Epoch 1966/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 51376.9688 - mean_absolute_error: 44.2087
# Epoch 1967/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 122142.9453 - mean_absolute_error: 64.9140
# Epoch 1968/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 359098.5312 - mean_absolute_error: 108.0707
# Epoch 1969/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 147346.1094 - mean_absolute_error: 83.3816
# Epoch 1970/2000
# 3/3 [==============================] - 0s 10ms/step - loss: 52545.1641 - mean_absolute_error: 52.5065
# Epoch 1971/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 364335.4688 - mean_absolute_error: 111.2432
# Epoch 1972/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 269190.5312 - mean_absolute_error: 76.7415
# Epoch 1973/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 73164.0000 - mean_absolute_error: 55.3825
# Epoch 1974/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 53957.0039 - mean_absolute_error: 47.3791
# Epoch 1975/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 90326.5078 - mean_absolute_error: 66.8194
# Epoch 1976/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 130600.4766 - mean_absolute_error: 78.3343
# Epoch 1977/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 113342.5781 - mean_absolute_error: 65.1153
# Epoch 1978/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 125020.6250 - mean_absolute_error: 66.0470
# Epoch 1979/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 140265.3750 - mean_absolute_error: 87.3047
# Epoch 1980/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 274194.6875 - mean_absolute_error: 105.4462
# Epoch 1981/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 214489.7812 - mean_absolute_error: 110.4655
# Epoch 1982/2000
# 3/3 [==============================] - 0s 9ms/step - loss: 1111158.3750 - mean_absolute_error: 128.9288
# Epoch 1983/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 366972.0000 - mean_absolute_error: 85.8886
# Epoch 1984/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 97767.3281 - mean_absolute_error: 68.8488
# Epoch 1985/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 81675.9141 - mean_absolute_error: 59.3399
# Epoch 1986/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 268884.3125 - mean_absolute_error: 77.7933
# Epoch 1987/2000
# 3/3 [==============================] - 0s 11ms/step - loss: 85266.2578 - mean_absolute_error: 62.5721
# Epoch 1988/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 141721.7656 - mean_absolute_error: 72.6067
# Epoch 1989/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 146941.9375 - mean_absolute_error: 83.9803
# Epoch 1990/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 179431.0625 - mean_absolute_error: 71.5937
# Epoch 1991/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 100234.2031 - mean_absolute_error: 75.1345
# Epoch 1992/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 59250.1016 - mean_absolute_error: 51.8391
# Epoch 1993/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 91372.4844 - mean_absolute_error: 50.0826
# Epoch 1994/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 230066.7969 - mean_absolute_error: 65.3243
# Epoch 1995/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 89156.7812 - mean_absolute_error: 65.1184
# Epoch 1996/2000
# 3/3 [==============================] - 0s 7ms/step - loss: 150654.4688 - mean_absolute_error: 82.3627
# Epoch 1997/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 149784.8438 - mean_absolute_error: 78.4408
# Epoch 1998/2000
# 3/3 [==============================] - 0s 6ms/step - loss: 347289.7812 - mean_absolute_error: 75.3082
# Epoch 1999/2000
# 3/3 [==============================] - 0s 8ms/step - loss: 181591.4062 - mean_absolute_error: 91.3834
# Epoch 2000/2000
# 3/3 [==============================] - 0s 5ms/step - loss: 112788.4609 - mean_absolute_error: 67.3308

# %% [markdown]
# ##Avaliando os residuos dos medelos
#
# https://medium.com/@krzysztofdrelczuk/acf-autocorrelation-function-simple-explanation-with-python-example-492484c32711

# %% [markdown]
# ###Regressao lasso
# Model: Lasso
# Best parameters: {'alpha': 84.79322206477522}
# Best cross-validation score: -240.0006812727942

# %%
predic_treino_lasso = lasso.predict(x_treino)

# %%
residuo_lasso = y_treino - predic_treino_lasso

# %%
plt.hist(residuo_lasso);

# %%
import statsmodels.api as sm

# %% [markdown]
# Gráfico ACF de resíduos
# Com dados de séries temporais, é altamente provável que o valor de uma variável observada no período de tempo atual seja semelhante ao seu valor no período anterior, ou mesmo no período anterior a esse, e assim por diante. Portanto, ao ajustar um modelo de regressão a dados de séries temporais, é comum encontrar autocorrelação nos resíduos. Nesse caso, o modelo estimado viola a suposição de não haver autocorrelação nos erros, e nossas previsões podem ser ineficientes — sobra alguma informação que deve ser contabilizada no modelo para obter melhores previsões. As previsões de um modelo com erros autocorrelacionados ainda não são viesadas e, portanto, não estão “erradas”, mas geralmente terão intervalos de previsão maiores do que o necessário. Portanto, devemos sempre olhar para um gráfico ACF dos resíduos.

# %%
sm.graphics.tsa.plot_acf(residuo_lasso,lags=40)
plt.show()

# %% [markdown]
# ###Random forest
# RandomForestRegressor(max_depth=100, max_features=15, min_samples_leaf=4,
#                       min_samples_split=8, n_estimators=20)

# %%
predic_rando_treino = rfr.predict(x_treino)

# %%
residuo_random = y_treino-predic_rando_treino

# %%
plt.hist(residuo_random);

# %%
sm.graphics.tsa.plot_acf(residuo_random,lags=40)
plt.show()

# %% [markdown]
# ###Gradiente Boosting
# {'learning_rate': 0.1,
#  'loss': 'lad',
#  'max_depth': 5,
#  'min_samples_leaf': 2,
#  'min_samples_split': 4,
#  'n_estimators': 500}

# %%
predict_grad_treino = grad_bost.predict(x_treino)

# %%
residuo_grad = y_treino - predict_grad_treino

# %%
plt.hist(residuo_grad,bins=50);

# %%
sm.graphics.tsa.plot_acf(residuo_grad,lags=40)
plt.show()

# %% [markdown]
# ###Redes neurais

# %%
predict_redes_treino = model.predict(x_treino)
# Out:
# 7/7 [==============================] - 0s 3ms/step

# %%
#Retirando um dimensao do array
predict_redes_treino = np.squeeze(predict_redes_treino)
predict_redes_treino
# Out:
# array([ 31.63622 ,  32.071983,  29.468168,  33.73252 ,  29.594526,
#         38.154022,  44.549446,  26.881235,  29.631098,  26.920721,
#         41.15452 ,  27.693745,  28.697992,  26.174599,  28.502645,
#         28.636852,  27.82737 ,  26.075924,  38.550144,  28.37015 ,
#         27.41715 ,  25.364147,  38.700714,  30.625875,  29.015463,
#         33.28126 ,  27.827808,  25.211218,  30.718588,  28.278292,
#         32.381695,  34.044823,  34.664738,  26.217224,  36.298126,
#         30.14306 ,  34.77525 ,  34.212116,  29.823265,  30.274721,
#         30.360167,  35.418655,  30.78721 ,  31.641722,  32.46483 ,
#         31.63597 ,  26.686548,  33.671658,  36.405914,  32.125114,
#         35.041767,  36.642   ,  32.39564 ,  36.789875,  35.347965,
#         34.9233  ,  32.610973,  23.956451,  38.103043,  29.703293,
#         37.87248 ,  61.856678,  31.699987,  28.981459,  38.898968,
#         34.052017,  43.127453,  34.11604 ,  44.23742 ,  32.490543,
#         36.79906 ,  36.711544,  43.45168 ,  34.089626,  34.089832,
#         39.39429 ,  29.44925 ,  30.710608,  29.143766,  31.145544,
#         29.680365,  28.593283,  25.975365,  37.682384,  44.24353 ,
#         28.823263,  29.533825,  36.71278 ,  34.002155,  33.399105,
#         33.284573,  35.691643,  32.950512,  35.332966,  30.369635,
#         46.945343,  34.89449 ,  35.284046,  34.72439 ,  38.004097,
#         35.12277 ,  38.13045 ,  39.46834 ,  36.934586,  42.090637,
#         40.594322,  37.751663,  35.385742,  43.552277,  48.07525 ,
#         37.261127,  42.04154 ,  37.074963,  40.75867 ,  47.693813,
#         39.544434,  38.29984 ,  50.31093 ,  43.585293,  42.150192,
#         40.76311 ,  69.274734,  38.737057,  40.029263,  46.131332,
#         42.031845,  36.11296 ,  45.17152 ,  40.681774,  50.15066 ,
#         49.349506,  46.267693,  49.559433,  41.26913 ,  70.93236 ,
#         35.01545 ,  54.68434 ,  43.143036,  39.9302  ,  52.46913 ,
#         45.06021 ,  45.487427,  55.79435 ,  47.196697,  51.1782  ,
#         52.447857,  60.025185,  39.98906 ,  58.108906,  52.825306,
#         54.711983,  48.46512 ,  50.454678,  44.303158,  44.594566,
#         51.08786 ,  58.532135,  56.427532,  51.73298 ,  47.978333,
#         46.9396  ,  45.482742,  44.026695,  45.61339 ,  46.934155,
#         37.030308,  39.328125,  47.18109 ,  51.813236,  47.526554,
#         44.286957,  55.035282,  39.5183  ,  44.684116,  43.654385,
#         41.937572,  44.9734  ,  34.833122,  37.10682 ,  53.37802 ,
#         49.39249 ,  44.01262 ,  48.14494 ,  59.882755,  42.852036,
#         47.515114,  44.175175,  41.93525 ,  41.469048,  34.4986  ,
#         45.776917,  46.311646,  55.001335,  43.58263 ,  53.24674 ,
#         51.636227,  45.00926 ,  46.645496,  42.510284,  42.416016,
#         42.45077 ,  31.557528,  39.879192,  37.72196 ,  39.736065,
#        350.26053 ,  45.604973,  60.54681 ,  29.156986,  47.586   ,
#         87.08432 ,  57.76391 ,  55.812115,  27.34324 ], dtype=float32)

# %%
residuo_neurais = y_treino - predict_redes_treino

# %%
plt.hist(residuo_neurais,bins=50);

# %%
sm.graphics.tsa.plot_acf(residuo_neurais,lags=40)
plt.show()

# %% [markdown]
# ##Avaliando os dados de treino

# %%
metrics_random_treino = evaluate_regression(y_treino,predic_rando_treino, 'Random Forest Regression')
metrics_linear_treino = evaluate_regression(y_treino,predic_treino_lasso, 'Linear Regression')
metrics_grad_treino = evaluate_regression(y_treino,predict_grad_treino, 'Gradiente Boosting Regression')
metrics_redes_treino = evaluate_regression(y_treino,predict_redes_treino, 'Redes Neurais')
metrics_treino = pd.concat([metrics_random_treino, metrics_linear_treino,metrics_grad_treino,metrics_redes_treino])
metrics_treino
# Out:
#                                 MAE     MSE  RMSE    R²
# Random Forest Regression       2.99   15.99  4.00  0.95
# Linear Regression              8.04  111.99 10.58  0.68
# Gradiente Boosting Regression  0.32    0.87  0.93  1.00
# Redes Neurais                 41.49 2261.16 47.55 -5.40

# %%
#Plotando as predicoes
plt.plot(treino.index,y_treino,label='Dados Reais')
plt.plot(treino.index,predict_redes_treino,label='Predição Redes Neurais')
plt.plot(treino.index,predic_treino_lasso,label='Regressão Lasso')
plt.plot(treino.index,predic_rando_treino,label='Predição Random Forest')
plt.plot(treino.index,predict_grad_treino,label='Gradient Boosting')
plt.legend();

# %% [markdown]
# ##Avaliando nos dados de teste

# %%
predic_teste_lasso = lasso.predict(x_teste)

# %%
predic_rando_teste = rfr.predict(x_teste)

# %%
predict_grad_teste = grad_bost.predict(x_teste)

# %%
predict_redes_teste = model.predict(x_teste)
predict_redes_teste = np.squeeze(predict_redes_teste)
# Out:
# 1/1 [==============================] - 0s 111ms/step

# %%
metrics_random_teste = evaluate_regression(y_teste,predic_rando_teste, 'Random Forest Regression')
metrics_linear_teste = evaluate_regression(y_teste,predic_teste_lasso, 'Linear Regression')
metrics_grad_teste = evaluate_regression(y_teste,predict_grad_teste, 'Gradiente Boosting Regression')
metrics_redes_teste = evaluate_regression(y_teste,predict_redes_teste, 'Redes Neurais')
metrics_teste = pd.concat([metrics_random_teste, metrics_linear_teste,metrics_grad_teste,metrics_redes_teste])
metrics_teste
# Out:
#                                 MAE     MSE  RMSE     R²
# Random Forest Regression      21.48  647.24 25.44 -14.08
# Linear Regression             25.92  938.29 30.63 -20.86
# Gradiente Boosting Regression 20.50  549.25 23.44 -11.80
# Redes Neurais                 49.65 2580.75 50.80 -59.13

# %%
#Plotando as predicoes
plt.plot(teste.index,y_teste,label='Dados Reais')
plt.plot(teste.index,predict_redes_teste,label='Predição Redes Neurais')
plt.plot(teste.index,predic_teste_lasso,label='Regressão Lasso')
plt.plot(teste.index,predic_rando_teste,label='Predição Random Forest')
plt.plot(teste.index,predict_grad_teste,label='Gradient Boosting')
plt.legend();

# %% [markdown]
# ##Intervalo de previsao

# %%
def intervalo_predicao_bootstraps(x_treino,y_treino,modelo_treinado,x_teste,index,predicao,nome_algoritimo,percentiles = [2.5, 97.5],n_bootstraps=1000):
  import numpy as np
  from sklearn.utils import resample

  # Bootstrap
  n_samples = len(x_treino)
  bootstrapped_predictions = np.zeros((n_bootstraps, len(x_teste)))
  
  if nome_algoritimo == 'Redes Neurais':
    for i in range(n_bootstraps):
      bootstrapped_data = resample(np.column_stack((x_treino, y_treino)), replace=True, n_samples=n_samples, random_state=i)
      bootstrapped_x_train, bootstrapped_y_train = bootstrapped_data[:, :-1], bootstrapped_data[:, -1]
      bootstrapped_model = modelo_treinado.fit(bootstrapped_x_train, bootstrapped_y_train, epochs=100,batch_size=100,verbose=0)
      bootstrapped_predictions[i] = np.squeeze(model.predict(x_teste))
  else:
    for i in range(n_bootstraps):
      bootstrapped_data = resample(np.column_stack((x_treino, y_treino)), replace=True, n_samples=n_samples, random_state=i)
      bootstrapped_x_train, bootstrapped_y_train = bootstrapped_data[:, :-1], bootstrapped_data[:, -1]
      bootstrapped_model = modelo_treinado.fit(bootstrapped_x_train, bootstrapped_y_train)
      bootstrapped_predictions[i] = bootstrapped_model.predict(x_teste)

  # Calcula intervalos de previsão
  lower = np.percentile(bootstrapped_predictions, percentiles[0], axis=0)
  upper = np.percentile(bootstrapped_predictions, percentiles[1], axis=0)

  intervalos = pd.DataFrame(index=index)
  intervalos['Predicao'] = predicao
  intervalos[f'lower({percentiles[0]})'] = lower
  intervalos[f'upper({percentiles[1]})'] = upper

  import matplotlib.pyplot as plt

  plt.plot(index,predicao,'*')
  plt.fill_between(index,lower, upper, color='gray', alpha=0.5, label=f'Intervalo de confiança de {percentiles[1]-percentiles[0]}%')
  plt.legend()
  plt.xlabel('Datas')
  plt.ylabel('Predição')
  plt.title('Previsões com intervalo de confiança para a'+' '+nome_algoritimo)
  plt.show()
  return intervalos

# %%
intervalo_random = intervalo_predicao_bootstraps(x_treino,y_treino,rfr,x_teste,teste.index,predic_rando_teste,'Random_Forest')

# %%
intervalo_random
# Out:
#             Predicao  lower(2.5)  upper(97.5)
# 2021-01-01     90.51       81.10        92.74
# 2021-02-01     91.92       86.96        98.56
# 2021-03-01     54.69       51.37        69.46
# 2021-04-01     65.03       51.44        73.89
# 2021-05-01     60.40       54.28        71.77
# 2021-06-01     56.04       54.68        69.85
# 2021-07-01     81.00       75.16        89.31
# 2021-08-01     88.80       82.21        92.00
# 2021-09-01     93.24       82.43        96.83
# 2021-10-01     96.69       88.67        99.61
# 2021-11-01     95.19       84.94       100.25
# 2021-12-01    101.36       89.07       105.65
# 2022-01-01     93.24       87.08        97.42
# 2022-02-01     89.84       87.37        97.71
# 2022-03-01     76.99       65.44        87.10
# 2022-04-01     57.93       54.51        70.38
# 2022-05-01     78.39       74.03        87.32
# 2022-06-01     77.83       67.66        83.24
# 2022-07-01     74.89       67.17        83.89
# 2022-08-01     70.58       62.84        81.39
# 2022-09-01     61.96       56.63        74.30
# 2022-10-01     68.78       58.64        78.48
# 2022-11-01     67.95       61.20        80.56
# 2022-12-01     68.94       60.51        78.00
# 2023-01-01     72.72       62.98        81.22
# 2023-02-01     70.08       60.35        79.39

# %%
intervalo_lasso = intervalo_predicao_bootstraps(x_treino,y_treino,lasso,x_teste,teste.index,predic_teste_lasso,'Regressão Lasso')

# %%
intervalo_lasso
# Out:
#             Predicao  lower(2.5)  upper(97.5)
# 2021-01-01     72.82       63.34        84.99
# 2021-02-01     82.05       75.08        90.54
# 2021-03-01     34.43        6.54        57.03
# 2021-04-01     38.80       26.37        47.18
# 2021-05-01     27.10       15.94        36.11
# 2021-06-01     60.44       53.59        67.91
# 2021-07-01     72.40       68.18        77.57
# 2021-08-01     81.65       74.60        90.09
# 2021-09-01     86.53       74.87        98.40
# 2021-10-01     90.20       86.12        94.90
# 2021-11-01     93.04       89.19        98.69
# 2021-12-01    103.85       98.07       111.23
# 2022-01-01     95.73       92.12        99.48
# 2022-02-01     93.57       91.38        96.27
# 2022-03-01     76.30       72.25        80.09
# 2022-04-01     67.78       62.56        71.94
# 2022-05-01     68.51       61.65        75.09
# 2022-06-01     67.36       62.88        71.51
# 2022-07-01     71.86       68.64        74.99
# 2022-08-01     71.29       66.41        75.51
# 2022-09-01     71.44       65.40        76.05
# 2022-10-01     74.65       68.48        79.70
# 2022-11-01     74.82       71.55        77.64
# 2022-12-01     72.17       68.86        74.65
# 2023-01-01     70.57       66.95        73.59
# 2023-02-01     70.48       66.56        73.64

# %%
intervalo_grad = intervalo_predicao_bootstraps(x_treino,y_treino,grad_bost,x_teste,teste.index,predict_grad_teste,'Gradiente Boosting',n_bootstraps=100)

# %%
intervalo_grad
# Out:
#             Predicao  lower(2.5)  upper(97.5)
# 2021-01-01     85.44       78.97        91.73
# 2021-02-01     89.45       83.78        95.19
# 2021-03-01     58.70       51.54        73.84
# 2021-04-01     71.05       54.00        74.93
# 2021-05-01     69.58       51.71        76.21
# 2021-06-01     65.37       53.76        77.03
# 2021-07-01     78.11       72.53        88.65
# 2021-08-01     83.23       78.97        90.41
# 2021-09-01     87.29       83.18        94.66
# 2021-10-01     89.32       84.44        96.05
# 2021-11-01     92.83       81.13        97.71
# 2021-12-01    102.17       90.63       103.84
# 2022-01-01     94.09       86.14        94.90
# 2022-02-01     89.57       81.63        93.75
# 2022-03-01     83.96       67.98        87.89
# 2022-04-01     65.03       54.42        73.45
# 2022-05-01     78.24       70.25        85.35
# 2022-06-01     70.20       65.33        77.68
# 2022-07-01     77.09       64.68        81.38
# 2022-08-01     76.03       61.87        78.96
# 2022-09-01     77.25       58.56        80.12
# 2022-10-01     67.40       58.17        73.37
# 2022-11-01     71.24       61.04        75.89
# 2022-12-01     66.94       57.44        72.04
# 2023-01-01     69.68       61.83        74.81
# 2023-02-01     67.59       58.76        72.81

# %%
intervalo_redes = intervalo_predicao_bootstraps(x_treino,y_treino,model,x_teste,teste.index,predict_redes_teste,'Redes Neurais',n_bootstraps=50)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step

# %%
intervalo_redes
# Out:
#             Predicao  lower(2.5)  upper(97.5)
# 2021-01-01     56.83       46.91        97.62
# 2021-02-01     55.97       46.89        89.24
# 2021-03-01     21.25       16.55       284.16
# 2021-04-01     30.09       26.52        46.12
# 2021-05-01     32.25       27.52        50.74
# 2021-06-01     44.28       37.69        69.48
# 2021-07-01     49.03       41.27        68.86
# 2021-08-01     55.62       44.48        88.63
# 2021-09-01     61.55       52.09       154.68
# 2021-10-01     56.10       46.14        78.94
# 2021-11-01     55.80       46.26        78.62
# 2021-12-01     55.81       46.61        78.42
# 2022-01-01     57.07       48.57        80.25
# 2022-02-01     54.93       45.99        77.31
# 2022-03-01     46.67       39.03        65.95
# 2022-04-01     42.83       35.34        61.52
# 2022-05-01     49.84       41.64        70.28
# 2022-06-01     47.40       38.26        66.74
# 2022-07-01     47.18       40.06        66.48
# 2022-08-01     46.45       39.58        65.49
# 2022-09-01     45.82       38.77        64.86
# 2022-10-01     48.19       38.90        68.94
# 2022-11-01     46.39       38.73        65.66
# 2022-12-01     46.14       38.45        65.52
# 2023-01-01     46.77       39.30        65.99
# 2023-02-01     46.98       40.00        66.24
