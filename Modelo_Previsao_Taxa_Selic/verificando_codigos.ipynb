# %%
from tratando_economic_brazil import metas_inflacao, tratando_metas_inflacao, tratando_dados_bcb, tratando_dados_ibge_codigos, tratando_dados_ibge_link, tratando_dados_expectativas
from datetime import datetime
import pandas as pd

# %%
dados = tratando_dados_expectativas()

# %%
dados.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-02-01', '2000-03-01', '2000-04-01',
#                '2000-05-01', '2000-06-01', '2000-07-01', '2000-08-01',
#                '2000-09-01', '2000-10-01',
#                ...
#                '2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#                '2024-03-01', '2024-04-01'],
#               dtype='datetime64[ns]', name='monthyear', length=292, freq='MS')

# %%
dados = tratando_metas_inflacao()

# %%
dados = metas_inflacao()

# %%
dados
# Out:
#     meta_inflacao   anos  inflacao_efetiva  diferenca_meta_efetiva
# 0           6.000   2000              5.97                   0.030
# 1           6.000   2000              5.97                   0.030
# 3           3.500   2002             12.53                  -9.030
# 4           3.254   2003              9.30                  -6.046
# 5           3.700   2004              7.60                  -3.900
# 6           4.500   2005              5.69                  -1.190
# 7           4.500   2006              3.14                   1.360
# 8           4.500   2007              4.46                   0.040
# 9           4.500   2008              5.90                  -1.400
# 10          4.500   2009              4.31                   0.190
# 11          4.500  2010               5.91                  -1.410
# 12          4.500   2011              6.50                  -2.000
# 13          4.500   2012              5.84                  -1.340
# ...
