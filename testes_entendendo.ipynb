# %%
from economic_brazil.economic_data_brazil import data_economic
from economic_brazil.codigos_graficos import plotar

# %%
dados = data_economic()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dados = data_economic(salvar=True,diretorio='dados/economic_data_brazil.csv')
#
# File /workspaces/Predicoes_macroeconomicas/economic_brazil/economic_data_brazil.py:41, in data_economic(codigos_banco_central, data_inicio, salvar, diretorio, formato, **kwargs)
#      39     if codigos_banco_central is None:
#      40         codigos_banco_central = SELIC_CODES
# ---> 41     dados = tratando_dados_bcb(
#      42         codigo_bcb_tratado=codigos_banco_central, data_inicio_tratada=data_inicio
#      43     )
#      45 if kwargs.get("expectativas_inflacao", True):
#      46     dados["expectativas_inflacao"] = tratando_dados_expectativas()
#
# ...

# %%
dados
# Out:
#             selic  IPCA-EX2  IPCA-EX3  IPCA-MS  IPCA-MA  IPCA-EX0  IPCA-EX1  \
# Date
# 2000-01-01  18.94      0.42      0.33     0.48     0.35      0.56      0.63
# 2000-02-01  18.87      0.17      0.21     0.44     0.35      0.45      0.32
# 2000-03-01  18.85     -0.11     -0.03     0.37     0.35      0.05      0.16
# 2000-04-01  18.62      0.16      0.22     0.45     0.35      0.87      0.62
# 2000-05-01  18.51      0.12      0.16     0.35     0.35      0.20      0.19
# ...           ...       ...       ...      ...      ...       ...       ...
# 2023-12-01  11.87      0.42      0.46     0.47     0.37      0.47      0.48
# 2024-01-01  11.65      0.59      0.61     0.51     0.37      0.16      0.22
# 2024-02-01  11.15      0.30      0.28     0.42     0.48      0.73      0.61
# 2024-03-01  11.00      0.25      0.21     0.24     0.15      0.01      0.10
# 2024-04-01  10.65      0.25      0.21     0.24     0.15      0.01      0.10
#
# ...

# %%
colunas_possiveis = ['selic', 'IPCA-EX2', 'IPCA-EX3', 'IPCA-MS', 'IPCA-MA', 'IPCA-EX0',
       'IPCA-EX1', 'IPCA-DP', 'expectativas_inflacao', 'meta_inflacao',
       'inflacao_efetiva', 'diferenca_meta_efetiva', 'ipca', 'pib',
       'despesas_publica', 'capital_fixo']

# %%
dados
# Out:
#             selic  IPCA-EX2  IPCA-EX3  IPCA-MS  IPCA-MA  IPCA-EX0  IPCA-EX1  \
# Date
# 2000-01-01  18.94      0.42      0.33     0.48     0.35      0.56      0.63
# 2000-02-01  18.87      0.17      0.21     0.44     0.35      0.45      0.32
# 2000-03-01  18.85     -0.11     -0.03     0.37     0.35      0.05      0.16
# 2000-04-01  18.62      0.16      0.22     0.45     0.35      0.87      0.62
# 2000-05-01  18.51      0.12      0.16     0.35     0.35      0.20      0.19
# ...           ...       ...       ...      ...      ...       ...       ...
# 2023-12-01  11.87      0.42      0.46     0.47     0.37      0.47      0.48
# 2024-01-01  11.65      0.59      0.61     0.51     0.37      0.16      0.22
# 2024-02-01  11.15      0.30      0.28     0.42     0.48      0.73      0.61
# 2024-03-01  11.00      0.25      0.21     0.24     0.15      0.01      0.10
# 2024-04-01  10.65      0.25      0.21     0.24     0.15      0.01      0.10
#
# ...

# %%
for column in dados.columns:
    if column in colunas_possiveis:
        print(True)
    else:
        print(False)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
